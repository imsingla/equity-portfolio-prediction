# %%
#import packages
from time import time
import datetime

import pandas as pd
import numpy as np
import quandl

#to plot within notebook
import matplotlib.pyplot as plt
# %matplotlib inline

#setting figure size
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20,10

#importing required libraries
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MinMaxScaler, Imputer
from sklearn.impute import SimpleImputer
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from keras.callbacks import TensorBoard
from fastai.structured import add_datepart

#to get stock OHCL data
from stocker import Stocker

quandl.ApiConfig.api_key = 'VGnWgTpUun-Lz-Aeh3gt'
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Verify Keras is using GPU

# %%
from keras import backend as K
K.tensorflow_backend._get_available_gpus()
# Out:
# ['/job:localhost/replica:0/task:0/device:GPU:0']

# %%
sp500 = ['MMM', 'ABT', 'ABBV', 'ABMD', 'ACN', 'ATVI', 'ADBE', 'AMD', 'AAP', 'AES', 'AMG', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALXN', 'ALGN', 'ALLE', 'AGN', 'ADS', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'APC', 'ADI', 'ANSS', 'ANTM', 'AON', 'AOS', 'APA', 'AIV', 'AAPL', 'AMAT', 'APTV', 'ADM', 'ARNC', 'ANET', 'AJG', 'AIZ', 'ATO', 'T', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'BHGE', 'BLL', 'BAC', 'BK', 'BAX', 'BBT', 'BDX', 'BRK.B', 'BBY', 'BIIB', 'BLK', 'HRB', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BHF', 'BMY', 'AVGO', 'BR', 'BF.B', 'CHRW', 'COG', 'CDNS', 'CPB', 'COF', 'CPRI', 'CAH', 'KMX', 'CCL', 'CAT', 'CBOE', 'CBRE', 'CBS', 'CE', 'CELG', 'CNC', 'CNP', 'CTL', 'CERN', 'CF', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'XEC', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CTXS', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'CXO', 'COP', 'ED', 'STZ', 'COO', 'CPRT', 'GLW', 'COST', 'COTY', 'CCI', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'FANG', 'DLR', 'DFS', 'DISCA', 'DISCK', 'DISH', 'DG', 'DLTR', 'D', 'DOV', 'DWDP', 'DTE', 'DRE', 'DUK', 'DXC', 'ETFC', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'EMR', 'ETR', 'EOG', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'EVRG', 'ES', 'RE', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FB', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FE', 'FRC', 'FISV', 'FLT', 'FLIR', 'FLS', 'FLR', 'FMC', 'FL', 'F', 'FTNT', 'FTV', 'FBHS', 'BEN', 'FCX', 'GPS', 'GRMN', 'IT', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GPN', 'GS', 'GWW', 'HAL', 'HBI', 'HOG', 'HRS', 'HIG', 'HAS', 'HCA', 'HCP', 'HP', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HFC', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HPQ', 'HUM', 'HBAN', 'HII', 'IDXX', 'INFO', 'ITW', 'ILMN', 'IR', 'INTC', 'ICE', 'IBM', 'INCY', 'IP', 'IPG', 'IFF', 'INTU', 'ISRG', 'IVZ', 'IPGP', 'IQV', 'IRM', 'JKHY', 'JEC', 'JBHT', 'JEF', 'SJM', 'JNJ', 'JCI', 'JPM', 'JNPR', 'KSU', 'K', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KSS', 'KHC', 'KR', 'LB', 'LLL', 'LH', 'LRCX', 'LW', 'LEG', 'LEN', 'LLY', 'LNC', 'LIN', 'LKQ', 'LMT', 'L', 'LOW', 'LYB', 'MTB', 'MAC', 'M', 'MRO', 'MPC', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MAT', 'MKC', 'MXIM', 'MCD', 'MCK', 'MDT', 'MRK', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MHK', 'TAP', 'MDLZ', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'MYL', 'NDAQ', 'NOV', 'NKTR', 'NTAP', 'NFLX', 'NWL', 'NEM', 'NWSA', 'NWS', 'NEE', 'NLSN', 'NKE', 'NI', 'NBL', 'JWN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'ORLY', 'OXY', 'OMC', 'OKE', 'ORCL', 'PCAR', 'PKG', 'PH', 'PAYX', 'PYPL', 'PNR', 'PBCT', 'PEP', 'PKI', 'PRGO', 'PFE', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'RL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PSA', 'PHM', 'PVH', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RJF', 'RTN', 'O', 'RHT', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'CRM', 'SBAC', 'SLB', 'STX', 'SEE', 'SRE', 'SHW', 'SPG', 'SWKS', 'SLG', 'SNA', 'SO', 'LUV', 'SPGI', 'SWK', 'SBUX', 'STT', 'SYK', 'STI', 'SIVB', 'SYMC', 'SYF', 'SNPS', 'SYY', 'TROW', 'TTWO', 'TPR', 'TGT', 'TEL', 'FTI', 'TFX', 'TXN', 'TXT', 'TMO', 'TIF', 'TWTR', 'TJX', 'TMK', 'TSS', 'TSCO', 'TDG', 'TRV', 'TRIP', 'FOXA', 'FOX', 'TSN', 'UDR', 'ULTA', 'USB', 'UAA', 'UA', 'UNP', 'UAL', 'UNH', 'UPS', 'URI', 'UTX', 'UHS', 'UNM', 'VFC', 'VLO', 'VAR', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VIAB', 'V', 'VNO', 'VMC', 'WAB', 'WMT', 'WBA', 'DIS', 'WM', 'WAT', 'WEC', 'WCG', 'WFC', 'WELL', 'WDC', 'WU', 'WRK', 'WY', 'WHR', 'WMB', 'WLTW', 'WYNN', 'XEL', 'XRX', 'XLNX', 'XYL', 'YUM', 'ZBH', 'ZION', 'ZTS']
best100 = ['msci', 'aig', 'cf', 'dte', 'gww', 're', 'apa', 'ual', 'ndaq', 'amp', 'pru', 'pcar', 'csx', 'dre', 'sna', 'rtn', 'ma', 'usb', 'o', 'hon', 'antm', 'wat', 'tfx', 'akam', 'sti', 'mnst', 'ads', 'dva', 'pep', 'wynn', 'mdlz', 'regn', 'incy', 'pnr', 'etr', 'tss', 'duk', 'mtb', 'ksu', 'fcx', 'aee', 'wfc', 'flir', 'sbac', 'vno', 'mat', 'zion', 'nwl', 'gd', 'amgn', 'mac', 'oxy', 'ed', 'sre', 'blk', 'pld', 'lmt', 'xel', 'gild', 'ctl', 'vlo', 'aes', 'aos', 'arnc', 'eqix', 'cof', 'k', 'es', 'dhr', 'hsy', 'pgr', 'irm', 'udr', 'amzn', 'bk', 'mmc', 'hcp', 'ppl', 'tgt', 'fmc', 'stt', 'ba', 'mcd', 'cme', 'ivz', 'axp', 'intc', 'xom', 'idxx', 'ess', 'amg', 'afl', 'ups', 'mo', 'omc', 'hum', 'swk', 'unm', 'cern', 'ce', 'unp']

# %%
# 10 years data
period = 365 * 10
# period of 10 years from 12-31-2017 backwards go back to 01-04-2008
date_range = ('01-01-2008', '12-31-2017')
max_stocker = '03-27-2018'
min_date = datetime.datetime.strptime(date_range[0], "%m-%d-%Y")
max_date = datetime.datetime.strptime(max_stocker, "%m-%d-%Y")

# %%
tickers = best100[:50]
tickerobjs = {} 
for ticker in tickers:
    tickerobjs[ticker] = (Stocker(ticker=ticker))
# Out:
# MSCI Stocker Initialized. Data covers 2007-11-15 to 2018-03-27.
# AIG Stocker Initialized. Data covers 1984-09-07 to 2018-03-27.
# CF Stocker Initialized. Data covers 2005-08-11 to 2018-03-27.
# DTE Stocker Initialized. Data covers 1970-01-02 to 2018-03-27.
# GWW Stocker Initialized. Data covers 1984-12-17 to 2018-03-27.
# RE Stocker Initialized. Data covers 1995-10-03 to 2018-03-27.
# APA Stocker Initialized. Data covers 1979-05-15 to 2018-03-27.
# UAL Stocker Initialized. Data covers 2006-02-06 to 2018-03-27.
# NDAQ Stocker Initialized. Data covers 2002-07-01 to 2018-03-27.
# AMP Stocker Initialized. Data covers 2005-09-15 to 2018-03-27.
# PRU Stocker Initialized. Data covers 2001-12-13 to 2018-03-27.
# PCAR Stocker Initialized. Data covers 1986-07-09 to 2018-03-27.
# CSX Stocker Initialized. Data covers 1980-11-03 to 2018-03-27.
# DRE Stocker Initialized. Data covers 1987-11-05 to 2018-03-27.
# SNA Stocker Initialized. Data covers 1985-07-01 to 2018-03-27.
# RTN Stocker Initialized. Data covers 1981-12-31 to 2018-03-27.
# MA Stocker Initialized. Data covers 2006-05-25 to 2018-03-27.
# USB Stocker Initialized. Data covers 1987-11-05 to 2018-03-27.
# O Stocker Initialized. Data covers 1994-10-18 to 2018-03-27.
# HON Stocker Initialized. Data covers 1970-01-02 to 2018-03-27.
# ANTM Stocker Initialized. Data covers 2001-10-30 to 2018-03-27.
# WAT Stocker Initialized. Data covers 1995-11-17 to 2018-03-27.
# TFX Stocker Initialized. Data covers 1988-02-18 to 2018-03-27.
# AKAM Stocker Initialized. Data covers 1999-10-29 to 2018-03-27.
# STI Stocker Initialized. Data covers 1987-12-30 to 2018-03-27.
# MNST Stocker Initialized. Data covers 1995-08-18 to 2018-03-27.
# ADS Stocker Initialized. Data covers 2001-06-15 to 2018-03-27.
# DVA Stocker Initialized. Data covers 1995-10-31 to 2018-03-27.
# PEP Stocker Initialized. Data covers 1972-06-01 to 2018-03-27.
# WYNN Stocker Initialized. Data covers 2002-10-25 to 2018-03-27.
# MDLZ Stocker Initialized. Data covers 2001-06-13 to 2018-03-27.
# REGN Stocker Initialized. Data covers 1991-04-02 to 2018-03-27.
# INCY Stocker Initialized. Data covers 1993-11-04 to 2018-03-27.
# PNR Stocker Initialized. Data covers 1973-05-03 to 2018-03-27.
# ETR Stocker Initialized. Data covers 1972-06-01 to 2018-03-27.
# TSS Stocker Initialized. Data covers 1989-06-30 to 2018-03-27.
# DUK Stocker Initialized. Data covers 1983-04-06 to 2018-03-27.
# MTB Stocker Initialized. Data covers 1991-10-04 to 2018-03-27.
# KSU Stocker Initialized. Data covers 1987-11-05 to 2018-03-27.
# FCX Stocker Initialized. Data covers 1995-07-10 to 2018-03-27.
# AEE Stocker Initialized. Data covers 1998-01-02 to 2018-03-27.
# WFC Stocker Initialized. Data covers 1972-06-01 to 2018-03-27.
# FLIR Stocker Initialized. Data covers 1993-06-22 to 2018-03-27.
# SBAC Stocker Initialized. Data covers 1999-06-16 to 2018-03-27.
# VNO Stocker Initialized. Data covers 1988-01-05 to 2018-03-27.
# MAT Stocker Initialized. Data covers 1982-01-04 to 2018-03-27.
# ZION Stocker Initialized. Data covers 1990-03-26 to 2018-03-27.
# NWL Stocker Initialized. Data covers 1984-07-19 to 2018-03-27.
# GD Stocker Initialized. Data covers 1977-01-03 to 2018-03-27.
# AMGN Stocker Initialized. Data covers 1984-09-07 to 2018-03-27.

# %%
for i, (k, v) in enumerate(tickerobjs.items()): 
    print(i, k, v)
# Out:
# 0 msci <stocker.Stocker object at 0x7fa72103f470>
# 1 aig <stocker.Stocker object at 0x7fa2d0609b00>
# 2 cf <stocker.Stocker object at 0x7fa2ccacf080>
# 3 dte <stocker.Stocker object at 0x7fa2d8f1ba90>
# 4 gww <stocker.Stocker object at 0x7fa72105a588>
# 5 re <stocker.Stocker object at 0x7fa2d8f57fd0>
# 6 apa <stocker.Stocker object at 0x7fa2d3ff1978>
# 7 ual <stocker.Stocker object at 0x7fa2d89c9a20>
# 8 ndaq <stocker.Stocker object at 0x7fa2ce987c50>
# 9 amp <stocker.Stocker object at 0x7fa2ccae1f28>
# 10 pru <stocker.Stocker object at 0x7fa2d8f3a860>
# 11 pcar <stocker.Stocker object at 0x7fa2ccb28080>
# 12 csx <stocker.Stocker object at 0x7fa2d8954ac8>
# 13 dre <stocker.Stocker object at 0x7fa72105a9e8>
# 14 sna <stocker.Stocker object at 0x7fa2d895ab38>
# 15 rtn <stocker.Stocker object at 0x7fa2d8960a90>
# 16 ma <stocker.Stocker object at 0x7fa72103f080>
# 17 usb <stocker.Stocker object at 0x7fa2cc9112b0>
# 18 o <stocker.Stocker object at 0x7fa2cc9113c8>
# 19 hon <stocker.Stocker object at 0x7fa2cc911390>
# 20 antm <stocker.Stocker object at 0x7fa2d88d0278>
# 21 wat <stocker.Stocker object at 0x7fa2d896bf98>
# 22 tfx <stocker.Stocker object at 0x7fa2d896ba58>
# 23 akam <stocker.Stocker object at 0x7fa2d896b9e8>
# 24 sti <stocker.Stocker object at 0x7fa2cc92bc88>
# 25 mnst <stocker.Stocker object at 0x7fa2cc92b7b8>
# 26 ads <stocker.Stocker object at 0x7fa2d8903630>
# 27 dva <stocker.Stocker object at 0x7fa2d88e5eb8>
# 28 pep <stocker.Stocker object at 0x7fa2d8903c18>
# 29 wynn <stocker.Stocker object at 0x7fa2d8903668>
# 30 mdlz <stocker.Stocker object at 0x7fa721031e10>
# 31 regn <stocker.Stocker object at 0x7fa72103f828>
# 32 incy <stocker.Stocker object at 0x7fa2d8903ef0>
# 33 pnr <stocker.Stocker object at 0x7fa2d88e5550>
# 34 etr <stocker.Stocker object at 0x7fa2d88e59b0>
# 35 tss <stocker.Stocker object at 0x7fa2d88e5240>
# 36 duk <stocker.Stocker object at 0x7fa2d88ed278>
# 37 mtb <stocker.Stocker object at 0x7fa2f2994240>
# 38 ksu <stocker.Stocker object at 0x7fa2ddd146d8>
# 39 fcx <stocker.Stocker object at 0x7fa3057c9e80>
# 40 aee <stocker.Stocker object at 0x7fa306b072e8>
# 41 wfc <stocker.Stocker object at 0x7fa2d89dfe80>
# 42 flir <stocker.Stocker object at 0x7fa2d8aee828>
# 43 sbac <stocker.Stocker object at 0x7fa2ddd82c18>
# 44 vno <stocker.Stocker object at 0x7fa2d70f0828>
# 45 mat <stocker.Stocker object at 0x7fa2e24ccb70>
# 46 zion <stocker.Stocker object at 0x7fa2d8fe8c18>
# 47 nwl <stocker.Stocker object at 0x7fa2d8fe8860>
# 48 gd <stocker.Stocker object at 0x7fa2d8fe8128>
# 49 amgn <stocker.Stocker object at 0x7fa720d44978>

# %% [markdown]
# ### Get sentiments

# %%
tickers_ciks = pd.read_csv('AllSecTickers.csv')
filing_sentiments = {}
for ticker in tickers:
    cik = int(tickers_ciks.loc[tickers_ciks['ticker'] == ticker]['cik'])
    fname = str(cik).zfill(10) + '.csv'
    
    tenQs = pd.read_csv(
        'sentiment-scores/10-Q/{}'.format(fname),
        names=['Cik','Coname','Date','Form','Secname','Neg_Score','Neu_Score','Pos_Score']
    )

    tenKs = pd.read_csv(
        'sentiment-scores/10-K/{}'.format(fname),
        names=['Cik','Coname','Date','Form','Secname','Neg_Score','Neu_Score','Pos_Score']
    )
    
    sentiments = pd.concat([tenQs, tenKs], ignore_index=True)
    sentiments['Date'] = pd.to_datetime(sentiments.Date, format='%Y-%m-%d')
    sentiments.index = sentiments['Date']
    sentiments = sentiments.sort_index(ascending=True, axis=0)
    
    filing_sentiments[ticker] = sentiments

# %% [markdown]
# ### Only keep stocks within the specified date range

# %%
finals = {}
for i, (k, v) in enumerate(tickerobjs.items()):
    try:
        if v.min_date.date() < min_date.date() and v.max_date.date() <= max_date.date():
            finals[k] = v
    except AttributeError:
        pass
print(len(finals))
tickerobjs = finals
# Out:
# 50

# %% [markdown]
# ### Date features

# %%
stocks_data = {}

for i, (ticker, stocker) in enumerate(tickerobjs.items()):
    df = stocker.make_df(date_range[0], date_range[1])
    # ddd date features
    add_datepart(df, 'Date', drop=False)
    # drop unwanted columns date feature columns
    df = df.drop(['Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start', 'Elapsed'], axis=1)
    df['Is_month_end'] = df['Is_month_end'].astype(int)
    df['Is_month_start'] = df['Is_month_start'].astype(int)
    # setting index as date
    df['Date'] = pd.to_datetime(df.Date,format='%Y-%m-%d')
    df.index = df['Date']
    # sort df by date
    df = df.sort_index(ascending=True, axis=0)
    
    stocks_data[ticker] = df
# Out:
# /home/rafay/portfolio-risk-assessment-using-ml/stocker.py:172: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   trim_df = df[(df['Date'] >= start_date.date()) &
# /home/rafay/portfolio-risk-assessment-using-ml/stocker.py:173: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   (df['Date'] <= end_date.date())]

# %% [markdown]
# ### Fix length issue

# %%
date_list = pd.date_range(start=date_range[0], end=date_range[1], freq='B')
date_df = pd.DataFrame(date_list).rename(columns={0: 'Date'})
date_df.index = date_df['Date']
date_df.rename(columns={'Date': 'Date2'}, inplace=True)

for i, (ticker, df) in enumerate(stocks_data.items()):
    stocks_data[ticker] = pd.concat([df, date_df], ignore_index=False, axis=1)

# %% [markdown]
# ### Combine sentiments data with DFs

# %%
for i, (ticker, df) in enumerate(stocks_data.items()):
    sentiment_df = filing_sentiments[ticker]
    forward_merged = pd.merge_asof(df, sentiment_df, left_index=True, right_index=True, direction='backward')
    stocks_data[ticker] = forward_merged

# %% [markdown]
# ### Print train, val and test count

# %%
TRAIN_SPLIT = 0.8  # 80% of total dataset
VAL_TEST_SPLIT = 0.5  # 50% of the remaining dataset

total_count = len(stocks_data[list(stocks_data.keys())[0]])
train_count = int(total_count * TRAIN_SPLIT)
left = total_count - train_count
valid_count = int(left * VAL_TEST_SPLIT)
test_count = int(left - valid_count)

print(sum([train_count, valid_count, test_count]))
total_count, train_count, valid_count, test_count
# Out:
# 2609
# (2609, 2087, 261, 261)

# %% [markdown]
# ### Create new dataset with required columns

# %%
pick_columns = {
    'Adj. Open', 'Adj. High', 'Adj. Low', 'Adj. Close', 'Adj. Volume', 'Month', 'Week', 'Day', 'Dayofweek', 
    'Dayofyear', 'Is_month_end', 'Is_month_start', 'Neg_Score'
}
y_column = {'Adj. Close'}
x_columns = pick_columns - y_column

for i, (ticker, df) in enumerate(stocks_data.items()):
    # creating new dataframe

    new_data = pd.DataFrame(df, columns=pick_columns).interpolate(limit_direction='both')
        
    x_df = pd.DataFrame(new_data, columns=x_columns)
    y_df = pd.DataFrame(new_data, columns=y_column)
    stocks_data[ticker] = {
        'x': x_df, 'y': y_df,
        'x_train': x_df[0:train_count], 'y_train': y_df[0:train_count],
        'x_valid': x_df[train_count:train_count+valid_count], 'y_valid': y_df[train_count:train_count+valid_count],
        'x_test': x_df[train_count+valid_count:], 'y_test': y_df[train_count+valid_count:],
        'new_data': new_data
    }

# %% [markdown]
# ### Verify just one

# %%
forward_merged = stocks_data['msci']['x']
forward_merged[forward_merged.index >= '2008-04-09'].head()
# Out:
#             Is_month_end  Adj. Volume  Is_month_start  Dayofyear  Week  \
# Date
# 2008-04-09           0.0     835100.0             0.0      100.0  15.0
# 2008-04-10           0.0     159500.0             0.0      101.0  15.0
# 2008-04-11           0.0     173800.0             0.0      102.0  15.0
# 2008-04-14           0.0     151000.0             0.0      105.0  16.0
# 2008-04-15           0.0      84500.0             0.0      106.0  16.0
#
#             Adj. Open  Adj. High  Neg_Score   Adj. Low   Day  Dayofweek  Month
# Date
# 2008-04-09  26.925191  28.262311   0.038033  23.712252   9.0        2.0    4.0
# 2008-04-10  28.993399  28.993399   0.038033  26.521168  10.0        3.0    4.0
# 2008-04-11  26.934810  27.887148   0.030889  26.097907  11.0        4.0    4.0
# 2008-04-14  26.742419  27.213778   0.030889  26.367255  14.0        0.0    4.0
# 2008-04-15  26.848234  27.059865   0.030889  25.741983  15.0        1.0    4.0

# %%
from numpy import hstack
from keras.preprocessing.sequence import TimeseriesGenerator

for i, (ticker, ds) in enumerate(stocks_data.items()):
    x_series = []
    y_series = []
    x_train_series = []
    y_train_series = []
    x_valid_series = []
    y_valid_series = []
    x_test_series = []
    y_test_series = []
    
    ds['x_values'] = ds['x'].values
    ds['y_values'] = ds['y'].values
    
    ds['x_train_values'] = ds['x_train'].values
    ds['y_train_values'] = ds['y_train'].values
    
    ds['x_valid_values'] = ds['x_valid'].values
    ds['y_valid_values'] = ds['y_valid'].values
    
    ds['x_test_values'] = ds['x_test'].values
    ds['y_test_values'] = ds['y_test'].values
    
    # Append values
    x_series.append(ds['x_values'])
    y_series.append(ds['y_values'])
    
    x_train_series.append(ds['x_train_values'])
    y_train_series.append(ds['y_train_values'])
    
    x_valid_series.append(ds['x_valid_values'])
    y_valid_series.append(ds['y_valid_values'])
    
    x_test_series.append(ds['x_test_values'])
    y_test_series.append(ds['y_test_values'])
    

    x_dataset = hstack(tuple(x_series))
    y_dataset = hstack(tuple(y_series))

    x_train_dataset = hstack(tuple(x_train_series))
    y_train_dataset = hstack(tuple(y_train_series))

    x_valid_dataset = hstack(tuple(x_valid_series))
    y_valid_dataset = hstack(tuple(y_valid_series))

    x_test_dataset = hstack(tuple(x_test_series))
    y_test_dataset = hstack(tuple(y_test_series))

    # fit scalers on full series
    x_scaler = MinMaxScaler(feature_range=(0, 1))
    y_scaler = MinMaxScaler(feature_range=(0, 1))

    x_dataset = x_scaler.fit_transform(x_dataset)
    y_dataset = y_scaler.fit_transform(y_dataset)
    
    # Scale train and validation datasets
    x_train_dataset = x_scaler.transform(x_train_dataset)
    y_train_dataset = y_scaler.transform(y_train_dataset)

    x_valid_dataset = x_scaler.transform(x_valid_dataset)
    y_valid_dataset = y_scaler.transform(y_valid_dataset)

    x_test_dataset = x_scaler.transform(x_test_dataset)
    y_test_dataset = y_scaler.transform(y_test_dataset)
    
    ds['x_train_dataset'] = x_train_dataset
    ds['y_train_dataset'] = y_train_dataset
    
    ds['x_valid_dataset'] = x_valid_dataset
    ds['y_valid_dataset'] = y_valid_dataset
    
    ds['x_test_dataset'] = x_test_dataset
    ds['y_test_dataset'] = y_test_dataset
    
    # Store feature scalers
    ds['x_scaler'] = x_scaler
    ds['y_scaler'] = y_scaler
    
    print('*' * 5 + 'Train shapes for ' + ticker)
    print(x_train_dataset.shape, y_train_dataset.shape) 
    
    print('*' * 5 + 'Validation shapes for ' + ticker)
    print(x_valid_dataset.shape, y_valid_dataset.shape) 
    
    print('*' * 5 + 'Test shapes for ' + ticker)
    print(x_test_dataset.shape, y_test_dataset.shape)
# Out:
# *****Train shapes for msci
# (2087, 12) (2087, 1)
# *****Validation shapes for msci
# (261, 12) (261, 1)
# *****Test shapes for msci
# (261, 12) (261, 1)
# *****Train shapes for aig
# (2087, 12) (2087, 1)
# *****Validation shapes for aig
# (261, 12) (261, 1)
# *****Test shapes for aig
# (261, 12) (261, 1)
# *****Train shapes for cf
# (2087, 12) (2087, 1)
# *****Validation shapes for cf
# (261, 12) (261, 1)
# *****Test shapes for cf
# (261, 12) (261, 1)
# *****Train shapes for dte
# (2087, 12) (2087, 1)
# *****Validation shapes for dte
# (261, 12) (261, 1)
# *****Test shapes for dte
# (261, 12) (261, 1)
# *****Train shapes for gww
# (2087, 12) (2087, 1)
# *****Validation shapes for gww
# (261, 12) (261, 1)
# *****Test shapes for gww
# (261, 12) (261, 1)
# *****Train shapes for re
# (2087, 12) (2087, 1)
# *****Validation shapes for re
# (261, 12) (261, 1)
# *****Test shapes for re
# (261, 12) (261, 1)
# *****Train shapes for apa
# (2087, 12) (2087, 1)
# *****Validation shapes for apa
# (261, 12) (261, 1)
# *****Test shapes for apa
# (261, 12) (261, 1)
# *****Train shapes for ual
# (2087, 12) (2087, 1)
# *****Validation shapes for ual
# (261, 12) (261, 1)
# *****Test shapes for ual
# (261, 12) (261, 1)
# *****Train shapes for ndaq
# (2087, 12) (2087, 1)
# *****Validation shapes for ndaq
# (261, 12) (261, 1)
# *****Test shapes for ndaq
# (261, 12) (261, 1)
# *****Train shapes for amp
# (2087, 12) (2087, 1)
# *****Validation shapes for amp
# (261, 12) (261, 1)
# *****Test shapes for amp
# (261, 12) (261, 1)
# *****Train shapes for pru
# (2087, 12) (2087, 1)
# *****Validation shapes for pru
# (261, 12) (261, 1)
# *****Test shapes for pru
# (261, 12) (261, 1)
# *****Train shapes for pcar
# (2087, 12) (2087, 1)
# *****Validation shapes for pcar
# (261, 12) (261, 1)
# *****Test shapes for pcar
# (261, 12) (261, 1)
# *****Train shapes for csx
# (2087, 12) (2087, 1)
# *****Validation shapes for csx
# (261, 12) (261, 1)
# *****Test shapes for csx
# (261, 12) (261, 1)
# *****Train shapes for dre
# (2087, 12) (2087, 1)
# *****Validation shapes for dre
# (261, 12) (261, 1)
# *****Test shapes for dre
# (261, 12) (261, 1)
# *****Train shapes for sna
# (2087, 12) (2087, 1)
# *****Validation shapes for sna
# (261, 12) (261, 1)
# *****Test shapes for sna
# (261, 12) (261, 1)
# *****Train shapes for rtn
# (2087, 12) (2087, 1)
# *****Validation shapes for rtn
# (261, 12) (261, 1)
# *****Test shapes for rtn
# (261, 12) (261, 1)
# *****Train shapes for ma
# (2087, 12) (2087, 1)
# *****Validation shapes for ma
# (261, 12) (261, 1)
# *****Test shapes for ma
# (261, 12) (261, 1)
# *****Train shapes for usb
# (2087, 12) (2087, 1)
# *****Validation shapes for usb
# (261, 12) (261, 1)
# *****Test shapes for usb
# (261, 12) (261, 1)
# *****Train shapes for o
# (2087, 12) (2087, 1)
# *****Validation shapes for o
# (261, 12) (261, 1)
# *****Test shapes for o
# (261, 12) (261, 1)
# *****Train shapes for hon
# (2087, 12) (2087, 1)
# *****Validation shapes for hon
# (261, 12) (261, 1)
# *****Test shapes for hon
# (261, 12) (261, 1)
# *****Train shapes for antm
# (2087, 12) (2087, 1)
# *****Validation shapes for antm
# (261, 12) (261, 1)
# *****Test shapes for antm
# (261, 12) (261, 1)
# *****Train shapes for wat
# (2087, 12) (2087, 1)
# *****Validation shapes for wat
# (261, 12) (261, 1)
# *****Test shapes for wat
# (261, 12) (261, 1)
# *****Train shapes for tfx
# (2087, 12) (2087, 1)
# *****Validation shapes for tfx
# (261, 12) (261, 1)
# *****Test shapes for tfx
# (261, 12) (261, 1)
# *****Train shapes for akam
# (2087, 12) (2087, 1)
# *****Validation shapes for akam
# (261, 12) (261, 1)
# *****Test shapes for akam
# (261, 12) (261, 1)
# *****Train shapes for sti
# (2087, 12) (2087, 1)
# *****Validation shapes for sti
# (261, 12) (261, 1)
# *****Test shapes for sti
# (261, 12) (261, 1)
# *****Train shapes for mnst
# (2087, 12) (2087, 1)
# *****Validation shapes for mnst
# (261, 12) (261, 1)
# *****Test shapes for mnst
# (261, 12) (261, 1)
# *****Train shapes for ads
# (2087, 12) (2087, 1)
# *****Validation shapes for ads
# (261, 12) (261, 1)
# *****Test shapes for ads
# (261, 12) (261, 1)
# *****Train shapes for dva
# (2087, 12) (2087, 1)
# *****Validation shapes for dva
# (261, 12) (261, 1)
# *****Test shapes for dva
# (261, 12) (261, 1)
# *****Train shapes for pep
# (2087, 12) (2087, 1)
# *****Validation shapes for pep
# (261, 12) (261, 1)
# *****Test shapes for pep
# (261, 12) (261, 1)
# *****Train shapes for wynn
# (2087, 12) (2087, 1)
# *****Validation shapes for wynn
# (261, 12) (261, 1)
# *****Test shapes for wynn
# (261, 12) (261, 1)
# *****Train shapes for mdlz
# (2087, 12) (2087, 1)
# *****Validation shapes for mdlz
# (261, 12) (261, 1)
# *****Test shapes for mdlz
# (261, 12) (261, 1)
# *****Train shapes for regn
# (2087, 12) (2087, 1)
# *****Validation shapes for regn
# (261, 12) (261, 1)
# *****Test shapes for regn
# (261, 12) (261, 1)
# *****Train shapes for incy
# (2087, 12) (2087, 1)
# *****Validation shapes for incy
# (261, 12) (261, 1)
# *****Test shapes for incy
# (261, 12) (261, 1)
# *****Train shapes for pnr
# (2087, 12) (2087, 1)
# *****Validation shapes for pnr
# (261, 12) (261, 1)
# *****Test shapes for pnr
# (261, 12) (261, 1)
# *****Train shapes for etr
# (2087, 12) (2087, 1)
# *****Validation shapes for etr
# (261, 12) (261, 1)
# *****Test shapes for etr
# (261, 12) (261, 1)
# *****Train shapes for tss
# (2087, 12) (2087, 1)
# *****Validation shapes for tss
# (261, 12) (261, 1)
# *****Test shapes for tss
# (261, 12) (261, 1)
# *****Train shapes for duk
# (2087, 12) (2087, 1)
# *****Validation shapes for duk
# (261, 12) (261, 1)
# *****Test shapes for duk
# (261, 12) (261, 1)
# *****Train shapes for mtb
# (2087, 12) (2087, 1)
# *****Validation shapes for mtb
# (261, 12) (261, 1)
# *****Test shapes for mtb
# (261, 12) (261, 1)
# *****Train shapes for ksu
# (2087, 12) (2087, 1)
# *****Validation shapes for ksu
# (261, 12) (261, 1)
# *****Test shapes for ksu
# (261, 12) (261, 1)
# *****Train shapes for fcx
# (2087, 12) (2087, 1)
# *****Validation shapes for fcx
# (261, 12) (261, 1)
# *****Test shapes for fcx
# (261, 12) (261, 1)
# *****Train shapes for aee
# (2087, 12) (2087, 1)
# *****Validation shapes for aee
# (261, 12) (261, 1)
# *****Test shapes for aee
# (261, 12) (261, 1)
# *****Train shapes for wfc
# (2087, 12) (2087, 1)
# *****Validation shapes for wfc
# (261, 12) (261, 1)
# *****Test shapes for wfc
# (261, 12) (261, 1)
# *****Train shapes for flir
# (2087, 12) (2087, 1)
# *****Validation shapes for flir
# (261, 12) (261, 1)
# *****Test shapes for flir
# (261, 12) (261, 1)
# *****Train shapes for sbac
# (2087, 12) (2087, 1)
# *****Validation shapes for sbac
# (261, 12) (261, 1)
# *****Test shapes for sbac
# (261, 12) (261, 1)
# *****Train shapes for vno
# (2087, 12) (2087, 1)
# *****Validation shapes for vno
# (261, 12) (261, 1)
# *****Test shapes for vno
# (261, 12) (261, 1)
# *****Train shapes for mat
# (2087, 12) (2087, 1)
# *****Validation shapes for mat
# (261, 12) (261, 1)
# *****Test shapes for mat
# (261, 12) (261, 1)
# *****Train shapes for zion
# (2087, 12) (2087, 1)
# *****Validation shapes for zion
# (261, 12) (261, 1)
# *****Test shapes for zion
# (261, 12) (261, 1)
# *****Train shapes for nwl
# (2087, 12) (2087, 1)
# *****Validation shapes for nwl
# (261, 12) (261, 1)
# *****Test shapes for nwl
# (261, 12) (261, 1)
# *****Train shapes for gd
# (2087, 12) (2087, 1)
# *****Validation shapes for gd
# (261, 12) (261, 1)
# *****Test shapes for gd
# (261, 12) (261, 1)
# *****Train shapes for amgn
# (2087, 12) (2087, 1)
# *****Validation shapes for amgn
# (261, 12) (261, 1)
# *****Test shapes for amgn
# (261, 12) (261, 1)

# %% [markdown]
# ### Create a TimeseriesGenerator

# %%
window_length = 90
BATCH_SIZE = int(window_length / 5)

for i, (ticker, ds) in enumerate(stocks_data.items()):
    x_train_dataset = ds['x_train_dataset']
    y_train_dataset = ds['y_train_dataset']
    
    x_valid_dataset = ds['x_valid_dataset']
    y_valid_dataset = ds['y_valid_dataset']
    
    x_test_dataset = ds['x_test_dataset']
    y_test_dataset = ds['y_test_dataset']
    
    train_generator = TimeseriesGenerator(x_train_dataset, y_train_dataset, length=window_length, batch_size=BATCH_SIZE)
    print('Train samples for {}: {}'.format(ticker, len(train_generator)))

    valid_generator = TimeseriesGenerator(x_valid_dataset, y_valid_dataset, length=window_length, batch_size=BATCH_SIZE)
    print('Validation samples for {}: {}'.format(ticker, len(valid_generator)))

    test_generator = TimeseriesGenerator(x_test_dataset, y_test_dataset, length=window_length, batch_size=BATCH_SIZE)
    print('Test samples for {}: {}'.format(ticker, len(test_generator)))
    
    ds['train_generator'] = train_generator
    ds['valid_generator'] = valid_generator
    ds['test_generator'] = test_generator
# Out:
# Train samples for msci: 111
# Validation samples for msci: 10
# Test samples for msci: 10
# Train samples for aig: 111
# Validation samples for aig: 10
# Test samples for aig: 10
# Train samples for cf: 111
# Validation samples for cf: 10
# Test samples for cf: 10
# Train samples for dte: 111
# Validation samples for dte: 10
# Test samples for dte: 10
# Train samples for gww: 111
# Validation samples for gww: 10
# Test samples for gww: 10
# Train samples for re: 111
# Validation samples for re: 10
# Test samples for re: 10
# Train samples for apa: 111
# Validation samples for apa: 10
# Test samples for apa: 10
# Train samples for ual: 111
# Validation samples for ual: 10
# Test samples for ual: 10
# Train samples for ndaq: 111
# Validation samples for ndaq: 10
# Test samples for ndaq: 10
# Train samples for amp: 111
# Validation samples for amp: 10
# Test samples for amp: 10
# Train samples for pru: 111
# Validation samples for pru: 10
# Test samples for pru: 10
# Train samples for pcar: 111
# Validation samples for pcar: 10
# Test samples for pcar: 10
# Train samples for csx: 111
# Validation samples for csx: 10
# Test samples for csx: 10
# Train samples for dre: 111
# Validation samples for dre: 10
# Test samples for dre: 10
# Train samples for sna: 111
# Validation samples for sna: 10
# Test samples for sna: 10
# Train samples for rtn: 111
# Validation samples for rtn: 10
# Test samples for rtn: 10
# Train samples for ma: 111
# Validation samples for ma: 10
# Test samples for ma: 10
# Train samples for usb: 111
# Validation samples for usb: 10
# Test samples for usb: 10
# Train samples for o: 111
# Validation samples for o: 10
# Test samples for o: 10
# Train samples for hon: 111
# Validation samples for hon: 10
# Test samples for hon: 10
# Train samples for antm: 111
# Validation samples for antm: 10
# Test samples for antm: 10
# Train samples for wat: 111
# Validation samples for wat: 10
# Test samples for wat: 10
# Train samples for tfx: 111
# Validation samples for tfx: 10
# Test samples for tfx: 10
# Train samples for akam: 111
# Validation samples for akam: 10
# Test samples for akam: 10
# Train samples for sti: 111
# Validation samples for sti: 10
# Test samples for sti: 10
# Train samples for mnst: 111
# Validation samples for mnst: 10
# Test samples for mnst: 10
# Train samples for ads: 111
# Validation samples for ads: 10
# Test samples for ads: 10
# Train samples for dva: 111
# Validation samples for dva: 10
# Test samples for dva: 10
# Train samples for pep: 111
# Validation samples for pep: 10
# Test samples for pep: 10
# Train samples for wynn: 111
# Validation samples for wynn: 10
# Test samples for wynn: 10
# Train samples for mdlz: 111
# Validation samples for mdlz: 10
# Test samples for mdlz: 10
# Train samples for regn: 111
# Validation samples for regn: 10
# Test samples for regn: 10
# Train samples for incy: 111
# Validation samples for incy: 10
# Test samples for incy: 10
# Train samples for pnr: 111
# Validation samples for pnr: 10
# Test samples for pnr: 10
# Train samples for etr: 111
# Validation samples for etr: 10
# Test samples for etr: 10
# Train samples for tss: 111
# Validation samples for tss: 10
# Test samples for tss: 10
# Train samples for duk: 111
# Validation samples for duk: 10
# Test samples for duk: 10
# Train samples for mtb: 111
# Validation samples for mtb: 10
# Test samples for mtb: 10
# Train samples for ksu: 111
# Validation samples for ksu: 10
# Test samples for ksu: 10
# Train samples for fcx: 111
# Validation samples for fcx: 10
# Test samples for fcx: 10
# Train samples for aee: 111
# Validation samples for aee: 10
# Test samples for aee: 10
# Train samples for wfc: 111
# Validation samples for wfc: 10
# Test samples for wfc: 10
# Train samples for flir: 111
# Validation samples for flir: 10
# Test samples for flir: 10
# Train samples for sbac: 111
# Validation samples for sbac: 10
# Test samples for sbac: 10
# Train samples for vno: 111
# Validation samples for vno: 10
# Test samples for vno: 10
# Train samples for mat: 111
# Validation samples for mat: 10
# Test samples for mat: 10
# Train samples for zion: 111
# Validation samples for zion: 10
# Test samples for zion: 10
# Train samples for nwl: 111
# Validation samples for nwl: 10
# Test samples for nwl: 10
# Train samples for gd: 111
# Validation samples for gd: 10
# Test samples for gd: 10
# Train samples for amgn: 111
# Validation samples for amgn: 10
# Test samples for amgn: 10

# %% [markdown]
# ### Fit LSTM Model

# %%
# EPOCHS = 20

# for i, (ticker, ds) in enumerate(stocks_data.items()):
#     train_generator = ds['train_generator']
#     valid_generator = ds['valid_generator']
#     test_generator = ds['test_generator']
    
#     OUTPUT_SIZE = 1
    
#     model = Sequential()
#     model.add(LSTM(units=50, return_sequences=True, input_shape=(window_length, OUTPUT_SIZE * len(x_columns))))
#     model.add(Dropout(0.2))
#     model.add(LSTM(units=50))
#     model.add(Dropout(0.2))
#     model.add(Dense(OUTPUT_SIZE))

#     model.compile(loss='mean_squared_error', optimizer='adam')

#     # Tensorboard
#     tensorboard = TensorBoard(log_dir='logs/{}-{}'.format(ticker, time()))
    
#     # Checkpoint
#     filepath='modelsneg/{}.weights.best.hdf5'.format(ticker)
# #     checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
#     callbacks_list = [tensorboard]
    
#     print('*' * 5 + 'Training for {}'.format(ticker))
#     model.fit_generator(
#         train_generator, 
#         validation_data=valid_generator, 
#         shuffle=False,
#         epochs=EPOCHS, 
#         verbose=1, 
#         callbacks=callbacks_list
#     )
#     model.save(filepath)
    
    
    
#     # --Plots while training
#     val_loss = model.evaluate_generator(valid_generator)
#     print('Val loss for {}: {}'.format(ticker, val_loss))
    
#     # Make test predictions
#     test_predict = model.predict_generator(test_generator)
#     predicted_df = pd.DataFrame(y_scaler.inverse_transform(test_predict))
#     predicted_df = predicted_df.rename(columns={0: ticker})
    
#     original_test = stocks_data[ticker]['y_test'].iloc[window_length:]
#     predicted_df.index = original_test.index
    
#     predicted_ticker = pd.concat([predicted_df[ticker], original_test], axis=1)
    
#     %matplotlib inline
#     plt.figure(figsize=(32, 20))

#     plt.plot(predicted_ticker[ticker], linewidth=1, alpha=0.8)
#     plt.plot(stocks_data[ticker]['y'], linewidth=1, alpha=0.8)
#     plt.title('Plot for {}, val loss: {}'.format(ticker.upper(), val_loss))
#     plt.savefig('plotsneg/{}'.format(ticker))
# #     plt.show()
# Out:
# *****Training for antm
# Epoch 1/20
# 111/111 [==============================] - 30s 273ms/step - loss: 0.0039 - val_loss: 0.0031
# Epoch 2/20
# 111/111 [==============================] - 24s 219ms/step - loss: 0.0058 - val_loss: 0.0023
# Epoch 3/20
# 111/111 [==============================] - 25s 223ms/step - loss: 0.0057 - val_loss: 0.0033
# Epoch 4/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0058 - val_loss: 0.0019
# Epoch 5/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0060 - val_loss: 0.0022
# Epoch 6/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0065 - val_loss: 0.0027
# Epoch 7/20
# 111/111 [==============================] - 25s 228ms/step - loss: 0.0067 - val_loss: 0.0021
# Epoch 8/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0077 - val_loss: 0.0073
# Epoch 9/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0070 - val_loss: 0.0236
# Epoch 10/20
# 111/111 [==============================] - 25s 223ms/step - loss: 0.0046 - val_loss: 0.0219
# Epoch 11/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0027 - val_loss: 0.0116
# Epoch 12/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0015 - val_loss: 0.0086
# Epoch 13/20
# 111/111 [==============================] - 25s 224ms/step - loss: 0.0011 - val_loss: 0.0052
# Epoch 14/20
# 111/111 [==============================] - 24s 213ms/step - loss: 8.5797e-04 - val_loss: 0.0035
# Epoch 15/20
# 111/111 [==============================] - 24s 219ms/step - loss: 7.1770e-04 - val_loss: 0.0019
# Epoch 16/20
# 111/111 [==============================] - 25s 223ms/step - loss: 6.3022e-04 - val_loss: 0.0026
# Epoch 17/20
# 111/111 [==============================] - 24s 213ms/step - loss: 6.2972e-04 - val_loss: 0.0016
# Epoch 18/20
# 111/111 [==============================] - 24s 213ms/step - loss: 6.4297e-04 - val_loss: 0.0024
# Epoch 19/20
# 111/111 [==============================] - 24s 214ms/step - loss: 6.5766e-04 - val_loss: 0.0030
# Epoch 20/20
# 111/111 [==============================] - 26s 237ms/step - loss: 7.5742e-04 - val_loss: 0.0030
# Val loss for antm: 0.0029973668692707036
# /home/rafay/miniconda3/envs/lstmstocks/lib/python3.6/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# *****Training for wat
# Epoch 1/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0116 - val_loss: 0.0152
# Epoch 2/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0093 - val_loss: 0.0024
# Epoch 3/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0110 - val_loss: 0.0043
# Epoch 4/20
# 111/111 [==============================] - 23s 212ms/step - loss: 0.0089 - val_loss: 0.0037
# Epoch 5/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0074 - val_loss: 0.0040
# Epoch 6/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0059 - val_loss: 0.0040
# Epoch 7/20
# 111/111 [==============================] - 24s 218ms/step - loss: 0.0047 - val_loss: 0.0034
# Epoch 8/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0032 - val_loss: 0.0021
# Epoch 9/20
# 111/111 [==============================] - 25s 221ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 10/20
# 111/111 [==============================] - 24s 216ms/step - loss: 0.0020 - val_loss: 0.0027
# Epoch 11/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 12/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0015 - val_loss: 0.0030
# Epoch 13/20
# 111/111 [==============================] - 25s 228ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 14/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0013 - val_loss: 0.0037
# Epoch 15/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0013 - val_loss: 0.0030
# Epoch 16/20
# 111/111 [==============================] - 25s 223ms/step - loss: 0.0015 - val_loss: 0.0028
# Epoch 17/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0015 - val_loss: 0.0030
# Epoch 18/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0014 - val_loss: 0.0037
# Epoch 19/20
# 111/111 [==============================] - 24s 219ms/step - loss: 0.0013 - val_loss: 0.0036
# Epoch 20/20
# 111/111 [==============================] - 25s 221ms/step - loss: 0.0013 - val_loss: 0.0045
# Val loss for wat: 0.004509630098350738
# *****Training for tfx
# Epoch 1/20
# 111/111 [==============================] - 25s 224ms/step - loss: 0.0046 - val_loss: 0.0171
# Epoch 2/20
# 111/111 [==============================] - 24s 220ms/step - loss: 0.0045 - val_loss: 0.0183
# Epoch 3/20
# 111/111 [==============================] - 24s 219ms/step - loss: 0.0040 - val_loss: 0.0310
# Epoch 4/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0036 - val_loss: 0.0329
# Epoch 5/20
# 111/111 [==============================] - 25s 225ms/step - loss: 0.0043 - val_loss: 0.0221
# Epoch 6/20
# 111/111 [==============================] - 25s 227ms/step - loss: 0.0046 - val_loss: 0.0211
# Epoch 7/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0057 - val_loss: 0.0362
# Epoch 8/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0066 - val_loss: 0.0138
# Epoch 9/20
# 111/111 [==============================] - 25s 224ms/step - loss: 0.0087 - val_loss: 0.0019
# Epoch 10/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0090 - val_loss: 0.0067
# Epoch 11/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0070 - val_loss: 0.0037
# Epoch 12/20
# 111/111 [==============================] - 25s 228ms/step - loss: 0.0045 - val_loss: 0.0126
# Epoch 13/20
# 111/111 [==============================] - 24s 216ms/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 14/20
# 111/111 [==============================] - 24s 215ms/step - loss: 8.4286e-04 - val_loss: 7.2543e-04
# Epoch 15/20
# 111/111 [==============================] - 24s 214ms/step - loss: 5.8827e-04 - val_loss: 9.8292e-04
# Epoch 16/20
# 111/111 [==============================] - 25s 225ms/step - loss: 5.9391e-04 - val_loss: 0.0012
# Epoch 17/20
# 111/111 [==============================] - 24s 215ms/step - loss: 5.7214e-04 - val_loss: 5.1925e-04
# Epoch 18/20
# 111/111 [==============================] - 25s 229ms/step - loss: 5.4891e-04 - val_loss: 5.1765e-04
# Epoch 19/20
# 111/111 [==============================] - 25s 227ms/step - loss: 4.5096e-04 - val_loss: 5.6212e-04
# Epoch 20/20
# 111/111 [==============================] - 24s 217ms/step - loss: 4.3626e-04 - val_loss: 0.0011
# Val loss for tfx: 0.001068101270663503
# *****Training for akam
# Epoch 1/20
# 111/111 [==============================] - 25s 228ms/step - loss: 0.0190 - val_loss: 0.0059
# Epoch 2/20
# 111/111 [==============================] - 25s 226ms/step - loss: 0.0205 - val_loss: 0.0070
# Epoch 3/20
# 111/111 [==============================] - 24s 216ms/step - loss: 0.0227 - val_loss: 0.0162
# Epoch 4/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0196 - val_loss: 0.0172
# Epoch 5/20
# 111/111 [==============================] - 25s 226ms/step - loss: 0.0147 - val_loss: 0.0163
# Epoch 6/20
# 111/111 [==============================] - 24s 218ms/step - loss: 0.0103 - val_loss: 0.0118
# Epoch 7/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0072 - val_loss: 0.0145
# Epoch 8/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0059 - val_loss: 0.0110
# Epoch 9/20
# 111/111 [==============================] - 24s 216ms/step - loss: 0.0060 - val_loss: 0.0115
# Epoch 10/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0056 - val_loss: 0.0130
# Epoch 11/20
# 111/111 [==============================] - 24s 220ms/step - loss: 0.0050 - val_loss: 0.0103
# Epoch 12/20
# 111/111 [==============================] - 24s 218ms/step - loss: 0.0043 - val_loss: 0.0060
# Epoch 13/20
# 111/111 [==============================] - 23s 208ms/step - loss: 0.0043 - val_loss: 0.0094
# Epoch 14/20
# 111/111 [==============================] - 23s 209ms/step - loss: 0.0038 - val_loss: 0.0071
# Epoch 15/20
# 111/111 [==============================] - 24s 217ms/step - loss: 0.0039 - val_loss: 0.0069
# Epoch 16/20
# 111/111 [==============================] - 23s 209ms/step - loss: 0.0037 - val_loss: 0.0074
# Epoch 17/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0039 - val_loss: 0.0075
# Epoch 18/20
# 111/111 [==============================] - 23s 209ms/step - loss: 0.0038 - val_loss: 0.0069
# Epoch 19/20
# 111/111 [==============================] - 24s 219ms/step - loss: 0.0038 - val_loss: 0.0094
# Epoch 20/20
# 111/111 [==============================] - 23s 208ms/step - loss: 0.0033 - val_loss: 0.0082
# Val loss for akam: 0.008241267115839659
# *****Training for sti
# Epoch 1/20
# 111/111 [==============================] - 24s 219ms/step - loss: 0.0406 - val_loss: 0.0044
# Epoch 2/20
# 111/111 [==============================] - 24s 219ms/step - loss: 0.0074 - val_loss: 0.0030
# Epoch 3/20
# 111/111 [==============================] - 24s 220ms/step - loss: 0.0067 - val_loss: 0.0027
# Epoch 4/20
# 111/111 [==============================] - 23s 212ms/step - loss: 0.0058 - val_loss: 0.0037
# Epoch 5/20
# 111/111 [==============================] - 24s 219ms/step - loss: 0.0050 - val_loss: 0.0029
# Epoch 6/20
# 111/111 [==============================] - 23s 209ms/step - loss: 0.0044 - val_loss: 0.0027
# Epoch 7/20
# 111/111 [==============================] - 23s 209ms/step - loss: 0.0039 - val_loss: 0.0036
# Epoch 8/20
# 111/111 [==============================] - 24s 217ms/step - loss: 0.0030 - val_loss: 0.0052
# Epoch 10/20
# 111/111 [==============================] - 24s 215ms/step - loss: 0.0029 - val_loss: 0.0050
# Epoch 11/20
# 111/111 [==============================] - 23s 208ms/step - loss: 0.0025 - val_loss: 0.0041
# Epoch 12/20
# 111/111 [==============================] - 24s 219ms/step - loss: 0.0023 - val_loss: 0.0031
# Epoch 13/20
# 111/111 [==============================] - 23s 209ms/step - loss: 0.0024 - val_loss: 0.0031
# Epoch 14/20
# 111/111 [==============================] - 23s 208ms/step - loss: 0.0024 - val_loss: 0.0040
# Epoch 15/20
# 111/111 [==============================] - 24s 216ms/step - loss: 0.0023 - val_loss: 0.0039
# Epoch 16/20
# 111/111 [==============================] - 24s 220ms/step - loss: 0.0024 - val_loss: 0.0038
# Epoch 17/20
# 111/111 [==============================] - 24s 216ms/step - loss: 0.0024 - val_loss: 0.0048
# Epoch 18/20
# 111/111 [==============================] - 23s 209ms/step - loss: 0.0023 - val_loss: 0.0042
# Epoch 19/20
# 111/111 [==============================] - 24s 219ms/step - loss: 0.0023 - val_loss: 0.0031
# Epoch 20/20
# 111/111 [==============================] - 23s 208ms/step - loss: 0.0022 - val_loss: 0.0041
# Val loss for sti: 0.004103662539579857
# *****Training for mnst
# Epoch 1/20
# 111/111 [==============================] - 24s 220ms/step - loss: 0.0081 - val_loss: 0.0305
# Epoch 2/20
# 111/111 [==============================] - 25s 226ms/step - loss: 0.0127 - val_loss: 0.0090
# Epoch 3/20
# 111/111 [==============================] - 23s 209ms/step - loss: 0.0120 - val_loss: 0.0179
# Epoch 4/20
# 111/111 [==============================] - 23s 208ms/step - loss: 0.0093 - val_loss: 0.0120
# Epoch 5/20
# 111/111 [==============================] - 24s 219ms/step - loss: 0.0063 - val_loss: 0.0050
# Epoch 6/20
# 111/111 [==============================] - 23s 209ms/step - loss: 0.0038 - val_loss: 0.0016
# Epoch 7/20
# 111/111 [==============================] - 23s 208ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 8/20
# 111/111 [==============================] - 23s 210ms/step - loss: 0.0014 - val_loss: 8.4837e-04
# Epoch 9/20
# 111/111 [==============================] - 26s 232ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 10/20
# 111/111 [==============================] - 23s 208ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 11/20
# 111/111 [==============================] - 23s 208ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 12/20
# 111/111 [==============================] - 24s 219ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 13/20
# 111/111 [==============================] - 23s 208ms/step - loss: 0.0010 - val_loss: 8.5674e-04
# Epoch 14/20
# 111/111 [==============================] - 23s 208ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 15/20
# 111/111 [==============================] - 25s 224ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 16/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 17/20
# 111/111 [==============================] - 23s 209ms/step - loss: 9.0467e-04 - val_loss: 6.3751e-04
# Epoch 18/20
# 111/111 [==============================] - 23s 209ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 19/20
# 111/111 [==============================] - 24s 219ms/step - loss: 0.0012 - val_loss: 7.6554e-04
# Epoch 20/20
# 111/111 [==============================] - 23s 208ms/step - loss: 0.0012 - val_loss: 3.8779e-04
# Val loss for mnst: 0.00038779050105643506
# *****Training for ads
# Epoch 1/20
# 111/111 [==============================] - 25s 223ms/step - loss: 0.0119 - val_loss: 0.0035
# Epoch 2/20
# 111/111 [==============================] - 25s 229ms/step - loss: 0.0133 - val_loss: 0.0036
# Epoch 3/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0174 - val_loss: 0.0016
# Epoch 4/20
# 111/111 [==============================] - 23s 210ms/step - loss: 0.0191 - val_loss: 0.0155
# Epoch 5/20
# 111/111 [==============================] - 24s 220ms/step - loss: 0.0247 - val_loss: 0.0383
# Epoch 6/20
# 111/111 [==============================] - 23s 210ms/step - loss: 0.0283 - val_loss: 0.0307
# Epoch 7/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0249 - val_loss: 0.0158
# Epoch 8/20
# 111/111 [==============================] - 24s 218ms/step - loss: 0.0123 - val_loss: 0.0045
# Epoch 9/20
# 111/111 [==============================] - 24s 215ms/step - loss: 0.0081 - val_loss: 0.0066
# Epoch 10/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0060 - val_loss: 0.0059
# Epoch 11/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 12/20
# 111/111 [==============================] - 25s 221ms/step - loss: 0.0030 - val_loss: 0.0049
# Epoch 13/20
# 111/111 [==============================] - 23s 210ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 14/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0027 - val_loss: 0.0014
# Epoch 15/20
# 111/111 [==============================] - 26s 234ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 16/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0021 - val_loss: 0.0026
# Epoch 17/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 18/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0020 - val_loss: 0.0030
# Epoch 19/20
# 111/111 [==============================] - 24s 219ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 20/20
# 111/111 [==============================] - 24s 216ms/step - loss: 0.0019 - val_loss: 0.0012
# Val loss for ads: 0.0011823674170667992
# *****Training for dva
# Epoch 1/20
# 111/111 [==============================] - 25s 225ms/step - loss: 0.0123 - val_loss: 0.0090
# Epoch 2/20
# 111/111 [==============================] - 24s 216ms/step - loss: 0.0130 - val_loss: 0.0191
# Epoch 3/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0155 - val_loss: 0.0154
# Epoch 4/20
# 111/111 [==============================] - 23s 209ms/step - loss: 0.0156 - val_loss: 0.0190
# Epoch 5/20
# 111/111 [==============================] - 24s 220ms/step - loss: 0.0125 - val_loss: 0.0065
# Epoch 6/20
# 111/111 [==============================] - 23s 208ms/step - loss: 0.0071 - val_loss: 0.0062
# Epoch 7/20
# 111/111 [==============================] - 24s 217ms/step - loss: 0.0045 - val_loss: 0.0048
# Epoch 8/20
# 111/111 [==============================] - 25s 228ms/step - loss: 0.0038 - val_loss: 0.0066
# Epoch 9/20
# 111/111 [==============================] - 23s 210ms/step - loss: 0.0033 - val_loss: 0.0083
# Epoch 10/20
# 111/111 [==============================] - 23s 209ms/step - loss: 0.0034 - val_loss: 0.0087
# Epoch 11/20
# 111/111 [==============================] - 23s 209ms/step - loss: 0.0029 - val_loss: 0.0125
# Epoch 12/20
# 111/111 [==============================] - 24s 220ms/step - loss: 0.0031 - val_loss: 0.0121
# Epoch 13/20
# 111/111 [==============================] - 24s 216ms/step - loss: 0.0029 - val_loss: 0.0137
# Epoch 14/20
# 111/111 [==============================] - 23s 208ms/step - loss: 0.0028 - val_loss: 0.0151
# Epoch 15/20
# 111/111 [==============================] - 24s 220ms/step - loss: 0.0026 - val_loss: 0.0130
# Epoch 16/20
# 111/111 [==============================] - 23s 210ms/step - loss: 0.0026 - val_loss: 0.0159
# Epoch 17/20
# 111/111 [==============================] - 23s 210ms/step - loss: 0.0024 - val_loss: 0.0182
# Epoch 18/20
# 111/111 [==============================] - 24s 215ms/step - loss: 0.0027 - val_loss: 0.0150
# Epoch 19/20
# 111/111 [==============================] - 24s 215ms/step - loss: 0.0027 - val_loss: 0.0184
# Epoch 20/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0028 - val_loss: 0.0205
# Val loss for dva: 0.02050263331559683
# *****Training for pep
# Epoch 1/20
# 111/111 [==============================] - 26s 235ms/step - loss: 0.0084 - val_loss: 0.0191
# Epoch 2/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0064 - val_loss: 0.0042
# Epoch 3/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0082 - val_loss: 0.0145
# Epoch 4/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0069 - val_loss: 0.0102
# Epoch 5/20
# 111/111 [==============================] - 25s 228ms/step - loss: 0.0056 - val_loss: 0.0137
# Epoch 6/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0042 - val_loss: 0.0068
# Epoch 7/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0034 - val_loss: 0.0045
# Epoch 8/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0028 - val_loss: 0.0016
# Epoch 9/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0019 - val_loss: 4.0412e-04
# Epoch 10/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0015 - val_loss: 4.8229e-04
# Epoch 11/20
# 111/111 [==============================] - 24s 218ms/step - loss: 0.0013 - val_loss: 3.9919e-04
# Epoch 12/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0013 - val_loss: 4.4869e-04
# Epoch 13/20
# 111/111 [==============================] - 25s 225ms/step - loss: 0.0010 - val_loss: 4.7298e-04
# Epoch 14/20
# 111/111 [==============================] - 23s 211ms/step - loss: 9.6569e-04 - val_loss: 4.0283e-04
# Epoch 15/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0012 - val_loss: 4.7446e-04
# Epoch 16/20
# 111/111 [==============================] - 23s 212ms/step - loss: 9.5540e-04 - val_loss: 7.9518e-04
# Epoch 17/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0010 - val_loss: 9.3886e-04
# Epoch 18/20
# 111/111 [==============================] - 25s 229ms/step - loss: 9.3686e-04 - val_loss: 0.0014
# Epoch 19/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0010 - val_loss: 9.9128e-04
# Epoch 20/20
# 111/111 [==============================] - 23s 212ms/step - loss: 0.0010 - val_loss: 9.4819e-04
# Val loss for pep: 0.0009481852849651324
# *****Training for wynn
# Epoch 1/20
# 111/111 [==============================] - 26s 236ms/step - loss: 0.0153 - val_loss: 0.0077
# Epoch 2/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0133 - val_loss: 0.0039
# Epoch 3/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0172 - val_loss: 0.0023
# Epoch 4/20
# 111/111 [==============================] - 25s 221ms/step - loss: 0.0205 - val_loss: 5.4008e-04
# Epoch 5/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0225 - val_loss: 7.7072e-04
# Epoch 6/20
# 111/111 [==============================] - 24s 217ms/step - loss: 0.0288 - val_loss: 0.0019
# Epoch 7/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0313 - val_loss: 0.0085
# Epoch 8/20
# 111/111 [==============================] - 24s 221ms/step - loss: 0.0292 - val_loss: 0.0103
# Epoch 9/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0239 - val_loss: 0.0087
# Epoch 10/20
# 111/111 [==============================] - 24s 218ms/step - loss: 0.0185 - val_loss: 0.0072
# Epoch 11/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0141 - val_loss: 0.0038
# Epoch 12/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0108 - val_loss: 0.0020
# Epoch 13/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0087 - val_loss: 0.0012
# Epoch 14/20
# 111/111 [==============================] - 24s 220ms/step - loss: 0.0071 - val_loss: 6.1077e-04
# Epoch 15/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0059 - val_loss: 3.9327e-04
# Epoch 16/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0053 - val_loss: 3.9340e-04
# Epoch 17/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0050 - val_loss: 4.3686e-04
# Epoch 18/20
# 111/111 [==============================] - 26s 235ms/step - loss: 0.0045 - val_loss: 4.3476e-04
# Epoch 19/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0042 - val_loss: 6.1826e-04
# Epoch 20/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0041 - val_loss: 4.8558e-04
# Val loss for wynn: 0.00048557668369061214
# *****Training for mdlz
# Epoch 1/20
# 111/111 [==============================] - 26s 234ms/step - loss: 0.0063 - val_loss: 0.0092
# Epoch 2/20
# 111/111 [==============================] - 24s 217ms/step - loss: 0.0170 - val_loss: 0.0048
# Epoch 3/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0217 - val_loss: 9.5012e-04
# Epoch 4/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0185 - val_loss: 0.0088
# Epoch 5/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0233 - val_loss: 0.0109
# Epoch 6/20
# 111/111 [==============================] - 23s 212ms/step - loss: 0.0250 - val_loss: 0.0021
# Epoch 7/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0146 - val_loss: 0.0027
# Epoch 8/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0064 - val_loss: 0.0018
# Epoch 9/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0038 - val_loss: 0.0020
# Epoch 10/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 11/20
# 111/111 [==============================] - 25s 228ms/step - loss: 0.0022 - val_loss: 0.0018
# Epoch 12/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0021 - val_loss: 0.0035
# Epoch 13/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 14/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 15/20
# 111/111 [==============================] - 24s 219ms/step - loss: 0.0017 - val_loss: 0.0046
# Epoch 16/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0017 - val_loss: 9.8747e-04
# Epoch 17/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0014 - val_loss: 0.0029
# Epoch 18/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 19/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0016 - val_loss: 8.4251e-04
# Epoch 20/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0016 - val_loss: 0.0055
# Val loss for mdlz: 0.005537323644507285
# *****Training for regn
# Epoch 1/20
# 111/111 [==============================] - 26s 230ms/step - loss: 0.0070 - val_loss: 0.0152
# Epoch 2/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0073 - val_loss: 0.0269
# Epoch 3/20
# 111/111 [==============================] - 26s 232ms/step - loss: 0.0093 - val_loss: 0.0137
# Epoch 4/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0105 - val_loss: 0.0303
# Epoch 5/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0120 - val_loss: 0.0201
# Epoch 6/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0099 - val_loss: 0.0397
# Epoch 7/20
# 111/111 [==============================] - 25s 226ms/step - loss: 0.0055 - val_loss: 0.0185
# Epoch 8/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0024 - val_loss: 0.0085
# Epoch 9/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0019 - val_loss: 0.0199
# Epoch 10/20
# 111/111 [==============================] - 25s 223ms/step - loss: 0.0018 - val_loss: 0.0148
# Epoch 11/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0017 - val_loss: 0.0280
# Epoch 12/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0016 - val_loss: 0.0060
# Epoch 13/20
# 111/111 [==============================] - 25s 221ms/step - loss: 0.0019 - val_loss: 0.0107
# Epoch 14/20
# 111/111 [==============================] - 24s 215ms/step - loss: 0.0017 - val_loss: 0.0153
# Epoch 15/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0018 - val_loss: 0.0137
# Epoch 16/20
# 111/111 [==============================] - 25s 226ms/step - loss: 0.0016 - val_loss: 0.0283
# Epoch 17/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0017 - val_loss: 0.0140
# Epoch 18/20
# 111/111 [==============================] - 23s 212ms/step - loss: 0.0018 - val_loss: 0.0305
# Epoch 19/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0018 - val_loss: 0.0314
# Epoch 20/20
# 111/111 [==============================] - 25s 229ms/step - loss: 0.0015 - val_loss: 0.0153
# Val loss for regn: 0.015320712896554093
# *****Training for incy
# Epoch 1/20
# 111/111 [==============================] - 25s 228ms/step - loss: 0.0114 - val_loss: 0.0027
# Epoch 2/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0088 - val_loss: 0.0166
# Epoch 3/20
# 111/111 [==============================] - 25s 223ms/step - loss: 0.0112 - val_loss: 0.0090
# Epoch 4/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0139 - val_loss: 0.0124
# Epoch 5/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0148 - val_loss: 0.0378
# Epoch 6/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0122 - val_loss: 0.0624
# Epoch 7/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0086 - val_loss: 0.0548
# Epoch 8/20
# 111/111 [==============================] - 25s 227ms/step - loss: 0.0207 - val_loss: 0.0066
# Epoch 9/20
# 111/111 [==============================] - 24s 220ms/step - loss: 0.0084 - val_loss: 0.0053
# Epoch 10/20
# 111/111 [==============================] - 24s 215ms/step - loss: 0.0036 - val_loss: 0.0025
# Epoch 11/20
# 111/111 [==============================] - 23s 212ms/step - loss: 0.0019 - val_loss: 0.0010
# Epoch 12/20
# 111/111 [==============================] - 24s 218ms/step - loss: 0.0012 - val_loss: 9.5763e-04
# Epoch 13/20
# 111/111 [==============================] - 25s 223ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 14/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 15/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 16/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0011 - val_loss: 0.0035
# Epoch 17/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 18/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 19/20
# 111/111 [==============================] - 24s 217ms/step - loss: 9.9328e-04 - val_loss: 0.0015
# Epoch 20/20
# 111/111 [==============================] - 24s 217ms/step - loss: 9.6104e-04 - val_loss: 0.0019
# Val loss for incy: 0.0018999614801846053
# *****Training for pnr
# Epoch 1/20
# 111/111 [==============================] - 27s 241ms/step - loss: 0.0127 - val_loss: 0.0065
# Epoch 2/20
# 111/111 [==============================] - 24s 221ms/step - loss: 0.0083 - val_loss: 0.0064
# Epoch 3/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0095 - val_loss: 0.0194
# Epoch 4/20
# 111/111 [==============================] - 24s 217ms/step - loss: 0.0097 - val_loss: 0.0022
# Epoch 5/20
# 111/111 [==============================] - 24s 217ms/step - loss: 0.0122 - val_loss: 0.0044
# Epoch 6/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0123 - val_loss: 0.0059
# Epoch 7/20
# 111/111 [==============================] - 23s 210ms/step - loss: 0.0165 - val_loss: 0.0028
# Epoch 8/20
# 111/111 [==============================] - 23s 210ms/step - loss: 0.0257 - val_loss: 0.0113
# Epoch 9/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0293 - val_loss: 0.0052
# Epoch 10/20
# 111/111 [==============================] - 23s 210ms/step - loss: 0.0248 - val_loss: 0.0015
# Epoch 11/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0207 - val_loss: 0.0016
# Epoch 12/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0151 - val_loss: 0.0014
# Epoch 13/20
# 111/111 [==============================] - 25s 221ms/step - loss: 0.0111 - val_loss: 0.0013
# Epoch 14/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0091 - val_loss: 0.0012
# Epoch 15/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0086 - val_loss: 0.0012
# Epoch 16/20
# 111/111 [==============================] - 25s 223ms/step - loss: 0.0081 - val_loss: 0.0012
# Epoch 17/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0079 - val_loss: 0.0011
# Epoch 18/20
# 111/111 [==============================] - 23s 210ms/step - loss: 0.0073 - val_loss: 0.0011
# Epoch 19/20
# 111/111 [==============================] - 25s 221ms/step - loss: 0.0073 - val_loss: 0.0011
# Epoch 20/20
# 111/111 [==============================] - 23s 210ms/step - loss: 0.0071 - val_loss: 0.0011
# Val loss for pnr: 0.0011361764336470515
# *****Training for etr
# Epoch 1/20
# 111/111 [==============================] - 26s 235ms/step - loss: 0.0266 - val_loss: 0.0687
# Epoch 2/20
# 111/111 [==============================] - 24s 219ms/step - loss: 0.0103 - val_loss: 0.0462
# Epoch 3/20
# 111/111 [==============================] - 24s 215ms/step - loss: 0.0065 - val_loss: 0.0271
# Epoch 4/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0055 - val_loss: 0.0235
# Epoch 5/20
# 111/111 [==============================] - 25s 228ms/step - loss: 0.0050 - val_loss: 0.0205
# Epoch 6/20
# 111/111 [==============================] - 25s 224ms/step - loss: 0.0038 - val_loss: 0.0069
# Epoch 7/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0029 - val_loss: 0.0133
# Epoch 8/20
# 111/111 [==============================] - 25s 224ms/step - loss: 0.0034 - val_loss: 0.0117
# Epoch 9/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0031 - val_loss: 0.0079
# Epoch 10/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0029 - val_loss: 0.0105
# Epoch 11/20
# 111/111 [==============================] - 24s 216ms/step - loss: 0.0033 - val_loss: 0.0137
# Epoch 12/20
# 111/111 [==============================] - 24s 218ms/step - loss: 0.0031 - val_loss: 0.0082
# Epoch 13/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0027 - val_loss: 0.0079
# Epoch 14/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0028 - val_loss: 0.0085
# Epoch 15/20
# 111/111 [==============================] - 25s 223ms/step - loss: 0.0028 - val_loss: 0.0057
# Epoch 16/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0021 - val_loss: 0.0039
# Epoch 17/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0022 - val_loss: 0.0085
# Epoch 18/20
# 111/111 [==============================] - 25s 227ms/step - loss: 0.0024 - val_loss: 0.0047
# Epoch 19/20
# 111/111 [==============================] - 24s 220ms/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 20/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0019 - val_loss: 0.0070
# Val loss for etr: 0.0069955835658076565
# *****Training for tss
# Epoch 1/20
# 111/111 [==============================] - 27s 247ms/step - loss: 0.0029 - val_loss: 0.0011
# Epoch 2/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0062 - val_loss: 0.0024
# Epoch 3/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0056 - val_loss: 0.0019
# Epoch 4/20
# 111/111 [==============================] - 25s 221ms/step - loss: 0.0064 - val_loss: 0.0084
# Epoch 5/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0080 - val_loss: 0.0057
# Epoch 6/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0087 - val_loss: 0.0114
# Epoch 7/20
# 111/111 [==============================] - 24s 217ms/step - loss: 0.0116 - val_loss: 0.0105
# Epoch 8/20
# 111/111 [==============================] - 24s 216ms/step - loss: 0.0122 - val_loss: 6.7034e-04
# Epoch 9/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0122 - val_loss: 9.4656e-04
# Epoch 10/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0070 - val_loss: 0.0077
# Epoch 11/20
# 111/111 [==============================] - 26s 230ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 12/20
# 111/111 [==============================] - 23s 211ms/step - loss: 9.4259e-04 - val_loss: 0.0016
# Epoch 13/20
# 111/111 [==============================] - 24s 218ms/step - loss: 0.0013 - val_loss: 7.6685e-04
# Epoch 14/20
# 111/111 [==============================] - 25s 222ms/step - loss: 7.6219e-04 - val_loss: 0.0017
# Epoch 15/20
# 111/111 [==============================] - 24s 213ms/step - loss: 9.8065e-04 - val_loss: 7.6574e-04
# Epoch 16/20
# 111/111 [==============================] - 24s 213ms/step - loss: 6.5343e-04 - val_loss: 0.0013
# Epoch 17/20
# 111/111 [==============================] - 24s 215ms/step - loss: 6.5990e-04 - val_loss: 7.5889e-04
# Epoch 18/20
# 111/111 [==============================] - 24s 218ms/step - loss: 6.9685e-04 - val_loss: 4.9116e-04
# Epoch 19/20
# 111/111 [==============================] - 24s 212ms/step - loss: 5.1284e-04 - val_loss: 4.7244e-04
# Epoch 20/20
# 111/111 [==============================] - 24s 213ms/step - loss: 5.6260e-04 - val_loss: 3.8357e-04
# Val loss for tss: 0.00038356970042897095
# *****Training for duk
# Epoch 1/20
# 111/111 [==============================] - 26s 237ms/step - loss: 0.0110 - val_loss: 0.0316
# Epoch 2/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0098 - val_loss: 0.0498
# Epoch 3/20
# 111/111 [==============================] - 26s 237ms/step - loss: 0.0097 - val_loss: 0.0405
# Epoch 4/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0084 - val_loss: 0.0498
# Epoch 5/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0069 - val_loss: 0.0376
# Epoch 6/20
# 111/111 [==============================] - 26s 231ms/step - loss: 0.0069 - val_loss: 0.0437
# Epoch 7/20
# 111/111 [==============================] - 25s 228ms/step - loss: 0.0069 - val_loss: 0.0321
# Epoch 8/20
# 111/111 [==============================] - 24s 220ms/step - loss: 0.0069 - val_loss: 0.0298
# Epoch 9/20
# 111/111 [==============================] - 24s 221ms/step - loss: 0.0060 - val_loss: 0.0316
# Epoch 10/20
# 111/111 [==============================] - 25s 229ms/step - loss: 0.0055 - val_loss: 0.0314
# Epoch 11/20
# 111/111 [==============================] - 24s 218ms/step - loss: 0.0051 - val_loss: 0.0235
# Epoch 12/20
# 111/111 [==============================] - 24s 217ms/step - loss: 0.0047 - val_loss: 0.0217
# Epoch 13/20
# 111/111 [==============================] - 25s 227ms/step - loss: 0.0045 - val_loss: 0.0266
# Epoch 14/20
# 111/111 [==============================] - 24s 220ms/step - loss: 0.0040 - val_loss: 0.0200
# Epoch 15/20
# 111/111 [==============================] - 25s 229ms/step - loss: 0.0038 - val_loss: 0.0222
# Epoch 16/20
# 111/111 [==============================] - 25s 225ms/step - loss: 0.0034 - val_loss: 0.0242
# Epoch 17/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0031 - val_loss: 0.0262
# Epoch 18/20
# 111/111 [==============================] - 24s 215ms/step - loss: 0.0030 - val_loss: 0.0265
# Epoch 19/20
# 111/111 [==============================] - 24s 215ms/step - loss: 0.0027 - val_loss: 0.0204
# Epoch 20/20
# 111/111 [==============================] - 25s 221ms/step - loss: 0.0029 - val_loss: 0.0234
# Val loss for duk: 0.023404109536817198
# *****Training for mtb
# Epoch 1/20
# 111/111 [==============================] - 27s 240ms/step - loss: 0.0090 - val_loss: 0.0052
# Epoch 2/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0087 - val_loss: 0.0050
# Epoch 3/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0114 - val_loss: 0.0064
# Epoch 4/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0091 - val_loss: 0.0042
# Epoch 5/20
# 111/111 [==============================] - 24s 217ms/step - loss: 0.0090 - val_loss: 0.0053
# Epoch 6/20
# 111/111 [==============================] - 24s 215ms/step - loss: 0.0087 - val_loss: 0.0046
# Epoch 7/20
# 111/111 [==============================] - 25s 225ms/step - loss: 0.0083 - val_loss: 0.0055
# Epoch 8/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0075 - val_loss: 0.0047
# Epoch 9/20
# 111/111 [==============================] - 25s 223ms/step - loss: 0.0067 - val_loss: 0.0050
# Epoch 10/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0063 - val_loss: 0.0046
# Epoch 11/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0050 - val_loss: 0.0043
# Epoch 12/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 13/20
# 111/111 [==============================] - 24s 216ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 14/20
# 111/111 [==============================] - 24s 215ms/step - loss: 0.0025 - val_loss: 0.0035
# Epoch 15/20
# 111/111 [==============================] - 25s 223ms/step - loss: 0.0020 - val_loss: 0.0035
# Epoch 16/20
# 111/111 [==============================] - 24s 218ms/step - loss: 0.0019 - val_loss: 0.0032
# Epoch 17/20
# 111/111 [==============================] - 24s 216ms/step - loss: 0.0017 - val_loss: 0.0040
# Epoch 18/20
# 111/111 [==============================] - 24s 216ms/step - loss: 0.0016 - val_loss: 0.0034
# Epoch 19/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0015 - val_loss: 0.0031
# Epoch 20/20
# 111/111 [==============================] - 25s 226ms/step - loss: 0.0016 - val_loss: 0.0027
# Val loss for mtb: 0.0027205557378597164
# *****Training for ksu
# Epoch 1/20
# 111/111 [==============================] - 28s 256ms/step - loss: 0.0175 - val_loss: 0.0076
# Epoch 2/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0102 - val_loss: 0.0165
# Epoch 3/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0121 - val_loss: 0.0148
# Epoch 4/20
# 111/111 [==============================] - 25s 223ms/step - loss: 0.0132 - val_loss: 0.0046
# Epoch 5/20
# 111/111 [==============================] - 24s 218ms/step - loss: 0.0157 - val_loss: 0.0063
# Epoch 6/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0180 - val_loss: 0.0014
# Epoch 7/20
# 111/111 [==============================] - 24s 216ms/step - loss: 0.0234 - val_loss: 0.0026
# Epoch 8/20
# 111/111 [==============================] - 25s 224ms/step - loss: 0.0266 - val_loss: 0.0039
# Epoch 9/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0231 - val_loss: 0.0017
# Epoch 10/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0196 - val_loss: 0.0018
# Epoch 11/20
# 111/111 [==============================] - 25s 224ms/step - loss: 0.0164 - val_loss: 0.0025
# Epoch 12/20
# 111/111 [==============================] - 25s 227ms/step - loss: 0.0134 - val_loss: 0.0027
# Epoch 13/20
# 111/111 [==============================] - 24s 220ms/step - loss: 0.0117 - val_loss: 0.0029
# Epoch 14/20
# 111/111 [==============================] - 25s 223ms/step - loss: 0.0108 - val_loss: 0.0033
# Epoch 15/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0098 - val_loss: 0.0032
# Epoch 16/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0090 - val_loss: 0.0027
# Epoch 17/20
# 111/111 [==============================] - 24s 215ms/step - loss: 0.0082 - val_loss: 0.0024
# Epoch 18/20
# 111/111 [==============================] - 25s 223ms/step - loss: 0.0079 - val_loss: 0.0023
# Epoch 19/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0078 - val_loss: 0.0020
# Epoch 20/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0073 - val_loss: 0.0013
# Val loss for ksu: 0.001319081982058522
# *****Training for fcx
# Epoch 1/20
# 111/111 [==============================] - 27s 244ms/step - loss: 0.0297 - val_loss: 0.0025
# Epoch 2/20
# 111/111 [==============================] - 24s 216ms/step - loss: 0.0131 - val_loss: 0.0011
# Epoch 3/20
# 111/111 [==============================] - 25s 229ms/step - loss: 0.0070 - val_loss: 4.1890e-04
# Epoch 4/20
# 111/111 [==============================] - 25s 224ms/step - loss: 0.0066 - val_loss: 0.0012
# Epoch 5/20
# 111/111 [==============================] - 24s 218ms/step - loss: 0.0072 - val_loss: 0.0013
# Epoch 6/20
# 111/111 [==============================] - 24s 220ms/step - loss: 0.0069 - val_loss: 0.0019
# Epoch 7/20
# 111/111 [==============================] - 24s 218ms/step - loss: 0.0082 - val_loss: 0.0011
# Epoch 8/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0056 - val_loss: 9.2577e-04
# Epoch 9/20
# 111/111 [==============================] - 24s 215ms/step - loss: 0.0062 - val_loss: 7.7551e-04
# Epoch 10/20
# 111/111 [==============================] - 25s 224ms/step - loss: 0.0048 - val_loss: 0.0011
# Epoch 11/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0056 - val_loss: 6.3905e-04
# Epoch 12/20
# 111/111 [==============================] - 24s 216ms/step - loss: 0.0042 - val_loss: 8.1123e-04
# Epoch 13/20
# 111/111 [==============================] - 25s 224ms/step - loss: 0.0051 - val_loss: 4.7677e-04
# Epoch 14/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0039 - val_loss: 5.7347e-04
# Epoch 15/20
# 111/111 [==============================] - 24s 215ms/step - loss: 0.0037 - val_loss: 5.0629e-04
# Epoch 16/20
# 111/111 [==============================] - 25s 228ms/step - loss: 0.0038 - val_loss: 4.6380e-04
# Epoch 17/20
# 111/111 [==============================] - 25s 224ms/step - loss: 0.0038 - val_loss: 4.7968e-04
# Epoch 18/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0036 - val_loss: 4.8256e-04
# Epoch 19/20
# 111/111 [==============================] - 24s 215ms/step - loss: 0.0033 - val_loss: 4.8729e-04
# Epoch 20/20
# 111/111 [==============================] - 25s 223ms/step - loss: 0.0030 - val_loss: 5.0536e-04
# Val loss for fcx: 0.0005053597644866003
# *****Training for aee
# Epoch 1/20
# 111/111 [==============================] - 27s 241ms/step - loss: 0.0090 - val_loss: 0.0608
# Epoch 2/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0037 - val_loss: 0.0304
# Epoch 3/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0045 - val_loss: 0.0288
# Epoch 4/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0047 - val_loss: 0.0301
# Epoch 5/20
# 111/111 [==============================] - 24s 217ms/step - loss: 0.0046 - val_loss: 0.0367
# Epoch 6/20
# 111/111 [==============================] - 24s 215ms/step - loss: 0.0046 - val_loss: 0.0412
# Epoch 7/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0051 - val_loss: 0.0345
# Epoch 8/20
# 111/111 [==============================] - 25s 225ms/step - loss: 0.0051 - val_loss: 0.0359
# Epoch 9/20
# 111/111 [==============================] - 25s 223ms/step - loss: 0.0057 - val_loss: 0.0365
# Epoch 10/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0054 - val_loss: 0.0349
# Epoch 11/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0055 - val_loss: 0.0337
# Epoch 12/20
# 111/111 [==============================] - 25s 223ms/step - loss: 0.0061 - val_loss: 0.0401
# Epoch 13/20
# 111/111 [==============================] - 23s 212ms/step - loss: 0.0060 - val_loss: 0.0397
# Epoch 14/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0060 - val_loss: 0.0364
# Epoch 15/20
# 111/111 [==============================] - 24s 216ms/step - loss: 0.0052 - val_loss: 0.0315
# Epoch 16/20
# 111/111 [==============================] - 24s 217ms/step - loss: 0.0047 - val_loss: 0.0312
# Epoch 17/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0040 - val_loss: 0.0307
# Epoch 18/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0035 - val_loss: 0.0299
# Epoch 19/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0029 - val_loss: 0.0287
# Epoch 20/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0024 - val_loss: 0.0266
# Val loss for aee: 0.026571429579665785
# *****Training for wfc
# Epoch 1/20
# 111/111 [==============================] - 28s 254ms/step - loss: 0.0130 - val_loss: 0.0021
# Epoch 2/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0088 - val_loss: 0.0027
# Epoch 3/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0078 - val_loss: 0.0040
# Epoch 4/20
# 111/111 [==============================] - 24s 220ms/step - loss: 0.0080 - val_loss: 0.0032
# Epoch 5/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0080 - val_loss: 0.0026
# Epoch 6/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0073 - val_loss: 0.0042
# Epoch 7/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0073 - val_loss: 0.0060
# Epoch 8/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0079 - val_loss: 0.0028
# Epoch 9/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0070 - val_loss: 0.0040
# Epoch 10/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0073 - val_loss: 0.0026
# Epoch 11/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0061 - val_loss: 0.0043
# Epoch 12/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0069 - val_loss: 0.0040
# Epoch 13/20
# 111/111 [==============================] - 25s 229ms/step - loss: 0.0064 - val_loss: 0.0044
# Epoch 14/20
# 111/111 [==============================] - 25s 221ms/step - loss: 0.0060 - val_loss: 0.0035
# Epoch 15/20
# 111/111 [==============================] - 24s 215ms/step - loss: 0.0106 - val_loss: 0.0327
# Epoch 4/20
# 111/111 [==============================] - 24s 215ms/step - loss: 0.0083 - val_loss: 0.0316
# Epoch 5/20
# 111/111 [==============================] - 25s 225ms/step - loss: 0.0072 - val_loss: 0.0123
# Epoch 6/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0083 - val_loss: 0.0270
# Epoch 7/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0062 - val_loss: 0.0154
# Epoch 8/20
# 111/111 [==============================] - 24s 218ms/step - loss: 0.0058 - val_loss: 0.0082
# Epoch 9/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0045 - val_loss: 0.0092
# Epoch 10/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0034 - val_loss: 0.0131
# Epoch 11/20
# 111/111 [==============================] - 24s 215ms/step - loss: 0.0024 - val_loss: 0.0147
# Epoch 12/20
# 111/111 [==============================] - 26s 238ms/step - loss: 0.0018 - val_loss: 0.0139
# Epoch 13/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0019 - val_loss: 0.0128
# Epoch 14/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0018 - val_loss: 0.0111
# Epoch 15/20
# 111/111 [==============================] - 25s 224ms/step - loss: 0.0018 - val_loss: 0.0117
# Epoch 16/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0018 - val_loss: 0.0121
# Epoch 17/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0016 - val_loss: 0.0103
# Epoch 18/20
# 111/111 [==============================] - 24s 219ms/step - loss: 0.0015 - val_loss: 0.0080
# Epoch 19/20
# 111/111 [==============================] - 24s 217ms/step - loss: 0.0015 - val_loss: 0.0131
# Epoch 20/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0015 - val_loss: 0.0119
# Val loss for nwl: 0.011868752024479602
# *****Training for gd
# Epoch 1/20
# 111/111 [==============================] - 29s 258ms/step - loss: 0.0089 - val_loss: 0.0085
# Epoch 2/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0059 - val_loss: 0.0027
# Epoch 3/20
# 111/111 [==============================] - 25s 226ms/step - loss: 0.0077 - val_loss: 0.0033
# Epoch 4/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0100 - val_loss: 0.0079
# Epoch 5/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0091 - val_loss: 0.0093
# Epoch 6/20
# 111/111 [==============================] - 23s 211ms/step - loss: 0.0080 - val_loss: 0.0105
# Epoch 7/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0074 - val_loss: 0.0064
# Epoch 8/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0073 - val_loss: 0.0038
# Epoch 9/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0072 - val_loss: 0.0024
# Epoch 10/20
# 111/111 [==============================] - 25s 223ms/step - loss: 0.0069 - val_loss: 0.0022
# Epoch 11/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0056 - val_loss: 0.0022
# Epoch 12/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0048 - val_loss: 0.0021
# Epoch 13/20
# 111/111 [==============================] - 24s 219ms/step - loss: 0.0037 - val_loss: 0.0022
# Epoch 14/20
# 111/111 [==============================] - 25s 224ms/step - loss: 0.0027 - val_loss: 0.0024
# Epoch 15/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 16/20
# 111/111 [==============================] - 25s 226ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 17/20
# 111/111 [==============================] - 25s 223ms/step - loss: 0.0016 - val_loss: 0.0033
# Epoch 18/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 19/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0013 - val_loss: 0.0026
# Epoch 20/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0012 - val_loss: 0.0038
# Val loss for gd: 0.003828167126477255
# *****Training for amgn
# Epoch 1/20
# 111/111 [==============================] - 29s 258ms/step - loss: 0.0043 - val_loss: 0.0026
# Epoch 2/20
# 111/111 [==============================] - 24s 219ms/step - loss: 0.0087 - val_loss: 0.0030
# Epoch 3/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0078 - val_loss: 0.0074
# Epoch 4/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0075 - val_loss: 0.0129
# Epoch 5/20
# 111/111 [==============================] - 25s 228ms/step - loss: 0.0049 - val_loss: 0.0110
# Epoch 6/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 7/20
# 111/111 [==============================] - 25s 227ms/step - loss: 0.0022 - val_loss: 0.0050
# Epoch 8/20
# 111/111 [==============================] - 25s 223ms/step - loss: 0.0019 - val_loss: 0.0043
# Epoch 9/20
# 111/111 [==============================] - 24s 213ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 10/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 11/20
# 111/111 [==============================] - 24s 215ms/step - loss: 0.0017 - val_loss: 0.0010
# Epoch 12/20
# 111/111 [==============================] - 24s 220ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 13/20
# 111/111 [==============================] - 24s 214ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 14/20
# 111/111 [==============================] - 24s 212ms/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 15/20
# 111/111 [==============================] - 25s 222ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 16/20
# 111/111 [==============================] - 23s 212ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 17/20
# 111/111 [==============================] - 24s 218ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 18/20
# 111/111 [==============================] - 25s 223ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 19/20
# 111/111 [==============================] - 24s 215ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 20/20
# 111/111 [==============================] - 25s 226ms/step - loss: 0.0012 - val_loss: 0.0011
# Val loss for amgn: 0.0011332020390239592

# %% [markdown]
# ### Final analysis

# %%
count = 0

for i, (ticker, ds) in enumerate(stocks_data.items()):
    train_generator = ds['train_generator']
    valid_generator = ds['valid_generator']
    test_generator = ds['test_generator']
    
    x_scaler = ds['x_scaler']
    y_scaler = ds['y_scaler']
    
    filepath='modelsneg/{}.weights.best.hdf5'.format(ticker)
    OUTPUT_SIZE = 1
    
    model = Sequential()
    model.add(LSTM(units=50, return_sequences=True, input_shape=(window_length, OUTPUT_SIZE * len(x_columns))))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50))
    model.add(Dropout(0.2))
    model.add(Dense(OUTPUT_SIZE))
    
    model.load_weights(filepath)

    model.compile(loss='mean_squared_error', optimizer='adam')
    
#     val_loss = model.evaluate_generator(valid_generator)
#     print('Val loss for {}: {}'.format(ticker, val_loss))
    
    # Make test predictions
    test_predict = model.predict_generator(test_generator)
    predicted_df = pd.DataFrame(y_scaler.inverse_transform(test_predict))
    predicted_df = predicted_df.rename(columns={0: ticker})
    
    original_test = stocks_data[ticker]['y_test'].iloc[window_length:]
    predicted_df.index = original_test.index
    
    if count > 0:
        predicted_ticker = pd.concat([predicted_df[ticker], predicted_ticker], axis=1)
    else: 
        predicted_ticker = predicted_df[ticker]
        
    count += 1
        
#     if count == 3: break
#     %matplotlib inline
#     plt.figure(figsize=(32, 20))

#     plt.plot(predicted_ticker[ticker], linewidth=1, alpha=0.8)
#     plt.plot(stocks_data[ticker]['y'], linewidth=1, alpha=0.8)
#     plt.title('Plot for {}, val loss: {}'.format(ticker.upper(), val_loss))

#     plt.show()

# %% [markdown]
# ### Save to csv file

# %%
predicted_ticker.to_csv('predicted_adj_close_50.csv')

# %% [markdown]
# ### Confirm result for msci

# %%
ticker = 'msci'
ds = stocks_data[ticker]

train_generator = ds['train_generator']
valid_generator = ds['valid_generator']
test_generator = ds['test_generator']

x_scaler = ds['x_scaler']
y_scaler = ds['y_scaler']

filepath='modelsneg/{}.weights.best.hdf5'.format(ticker)
OUTPUT_SIZE = 1

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(window_length, OUTPUT_SIZE * len(x_columns))))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(OUTPUT_SIZE))

model.load_weights(filepath)

model.compile(loss='mean_squared_error', optimizer='adam')

val_loss = model.evaluate_generator(valid_generator)
print('Val loss for {}: {}'.format(ticker, val_loss))

# Make test predictions
test_predict = model.predict_generator(test_generator)
predicted_df = pd.DataFrame(y_scaler.inverse_transform(test_predict))
predicted_df = predicted_df.rename(columns={0: ticker})

original_test = stocks_data[ticker]['y_test'].iloc[window_length:]
predicted_df.index = original_test.index

predicted_ticker = pd.concat([predicted_df[ticker], predicted_df[ticker]], axis=1)

# %matplotlib inline
# plt.figure(figsize=(32, 20))

# plt.plot(predicted_ticker[ticker], linewidth=1, alpha=0.8)
# plt.plot(stocks_data[ticker]['y'], linewidth=1, alpha=0.8)
# plt.title('Plot for {}, val loss: {}'.format(ticker.upper(), val_loss))

# plt.show()
# Out:
# Val loss for msci: 0.010379942593556879
