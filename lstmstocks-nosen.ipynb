# %%
#import packages
from time import time
import datetime

import pandas as pd
import numpy as np
import quandl

#to plot within notebook
import matplotlib.pyplot as plt
# %matplotlib inline

#setting figure size
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20,10

#importing required libraries
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MinMaxScaler, Imputer
from sklearn.impute import SimpleImputer
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from keras.callbacks import TensorBoard, ModelCheckpoint
from fastai.structured import add_datepart

#to get stock OHCL data
from stocker import Stocker

quandl.ApiConfig.api_key = 'VGnWgTpUun-Lz-Aeh3gt'
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Verify Keras is using GPU

# %%
from keras import backend as K
K.tensorflow_backend._get_available_gpus()
# Out:
# ['/job:localhost/replica:0/task:0/device:GPU:0']

# %%
sp500 = ['MMM', 'ABT', 'ABBV', 'ABMD', 'ACN', 'ATVI', 'ADBE', 'AMD', 'AAP', 'AES', 'AMG', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALXN', 'ALGN', 'ALLE', 'AGN', 'ADS', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'APC', 'ADI', 'ANSS', 'ANTM', 'AON', 'AOS', 'APA', 'AIV', 'AAPL', 'AMAT', 'APTV', 'ADM', 'ARNC', 'ANET', 'AJG', 'AIZ', 'ATO', 'T', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'BHGE', 'BLL', 'BAC', 'BK', 'BAX', 'BBT', 'BDX', 'BRK.B', 'BBY', 'BIIB', 'BLK', 'HRB', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BHF', 'BMY', 'AVGO', 'BR', 'BF.B', 'CHRW', 'COG', 'CDNS', 'CPB', 'COF', 'CPRI', 'CAH', 'KMX', 'CCL', 'CAT', 'CBOE', 'CBRE', 'CBS', 'CE', 'CELG', 'CNC', 'CNP', 'CTL', 'CERN', 'CF', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'XEC', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CTXS', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'CXO', 'COP', 'ED', 'STZ', 'COO', 'CPRT', 'GLW', 'COST', 'COTY', 'CCI', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'FANG', 'DLR', 'DFS', 'DISCA', 'DISCK', 'DISH', 'DG', 'DLTR', 'D', 'DOV', 'DWDP', 'DTE', 'DRE', 'DUK', 'DXC', 'ETFC', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'EMR', 'ETR', 'EOG', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'EVRG', 'ES', 'RE', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FB', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FE', 'FRC', 'FISV', 'FLT', 'FLIR', 'FLS', 'FLR', 'FMC', 'FL', 'F', 'FTNT', 'FTV', 'FBHS', 'BEN', 'FCX', 'GPS', 'GRMN', 'IT', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GPN', 'GS', 'GWW', 'HAL', 'HBI', 'HOG', 'HRS', 'HIG', 'HAS', 'HCA', 'HCP', 'HP', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HFC', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HPQ', 'HUM', 'HBAN', 'HII', 'IDXX', 'INFO', 'ITW', 'ILMN', 'IR', 'INTC', 'ICE', 'IBM', 'INCY', 'IP', 'IPG', 'IFF', 'INTU', 'ISRG', 'IVZ', 'IPGP', 'IQV', 'IRM', 'JKHY', 'JEC', 'JBHT', 'JEF', 'SJM', 'JNJ', 'JCI', 'JPM', 'JNPR', 'KSU', 'K', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KSS', 'KHC', 'KR', 'LB', 'LLL', 'LH', 'LRCX', 'LW', 'LEG', 'LEN', 'LLY', 'LNC', 'LIN', 'LKQ', 'LMT', 'L', 'LOW', 'LYB', 'MTB', 'MAC', 'M', 'MRO', 'MPC', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MAT', 'MKC', 'MXIM', 'MCD', 'MCK', 'MDT', 'MRK', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MHK', 'TAP', 'MDLZ', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'MYL', 'NDAQ', 'NOV', 'NKTR', 'NTAP', 'NFLX', 'NWL', 'NEM', 'NWSA', 'NWS', 'NEE', 'NLSN', 'NKE', 'NI', 'NBL', 'JWN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'ORLY', 'OXY', 'OMC', 'OKE', 'ORCL', 'PCAR', 'PKG', 'PH', 'PAYX', 'PYPL', 'PNR', 'PBCT', 'PEP', 'PKI', 'PRGO', 'PFE', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'RL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PSA', 'PHM', 'PVH', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RJF', 'RTN', 'O', 'RHT', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'CRM', 'SBAC', 'SLB', 'STX', 'SEE', 'SRE', 'SHW', 'SPG', 'SWKS', 'SLG', 'SNA', 'SO', 'LUV', 'SPGI', 'SWK', 'SBUX', 'STT', 'SYK', 'STI', 'SIVB', 'SYMC', 'SYF', 'SNPS', 'SYY', 'TROW', 'TTWO', 'TPR', 'TGT', 'TEL', 'FTI', 'TFX', 'TXN', 'TXT', 'TMO', 'TIF', 'TWTR', 'TJX', 'TMK', 'TSS', 'TSCO', 'TDG', 'TRV', 'TRIP', 'FOXA', 'FOX', 'TSN', 'UDR', 'ULTA', 'USB', 'UAA', 'UA', 'UNP', 'UAL', 'UNH', 'UPS', 'URI', 'UTX', 'UHS', 'UNM', 'VFC', 'VLO', 'VAR', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VIAB', 'V', 'VNO', 'VMC', 'WAB', 'WMT', 'WBA', 'DIS', 'WM', 'WAT', 'WEC', 'WCG', 'WFC', 'WELL', 'WDC', 'WU', 'WRK', 'WY', 'WHR', 'WMB', 'WLTW', 'WYNN', 'XEL', 'XRX', 'XLNX', 'XYL', 'YUM', 'ZBH', 'ZION', 'ZTS']
best100 = ['msci', 'aig', 'cf', 'dte', 'gww', 're', 'apa', 'ual', 'ndaq', 'amp', 'pru', 'pcar', 'csx', 'dre', 'sna', 'rtn', 'ma', 'usb', 'o', 'hon', 'antm', 'wat', 'tfx', 'akam', 'sti', 'mnst', 'ads', 'dva', 'pep', 'wynn', 'mdlz', 'regn', 'incy', 'pnr', 'etr', 'tss', 'duk', 'mtb', 'ksu', 'fcx', 'aee', 'wfc', 'flir', 'sbac', 'vno', 'mat', 'zion', 'nwl', 'gd', 'amgn', 'mac', 'oxy', 'ed', 'sre', 'blk', 'pld', 'lmt', 'xel', 'gild', 'ctl', 'vlo', 'aes', 'aos', 'arnc', 'eqix', 'cof', 'k', 'es', 'dhr', 'hsy', 'pgr', 'irm', 'udr', 'amzn', 'bk', 'mmc', 'hcp', 'ppl', 'tgt', 'fmc', 'stt', 'ba', 'mcd', 'cme', 'ivz', 'axp', 'intc', 'xom', 'idxx', 'ess', 'amg', 'afl', 'ups', 'mo', 'omc', 'hum', 'swk', 'unm', 'cern', 'ce', 'unp']

# %%
# 10 years data
period = 365 * 10
# period of 10 years from 12-31-2017 backwards go back to 01-04-2008
date_range = ('01-01-2008', '12-31-2017')
max_stocker = '03-27-2018'
min_date = datetime.datetime.strptime(date_range[0], "%m-%d-%Y")
max_date = datetime.datetime.strptime(max_stocker, "%m-%d-%Y")

# %%
tickers = best100[41:50]
tickerobjs = {} 
for ticker in tickers:
    tickerobjs[ticker] = (Stocker(ticker=ticker))
# Out:
# WFC Stocker Initialized. Data covers 1972-06-01 to 2018-03-27.
# FLIR Stocker Initialized. Data covers 1993-06-22 to 2018-03-27.
# SBAC Stocker Initialized. Data covers 1999-06-16 to 2018-03-27.
# VNO Stocker Initialized. Data covers 1988-01-05 to 2018-03-27.
# MAT Stocker Initialized. Data covers 1982-01-04 to 2018-03-27.
# ZION Stocker Initialized. Data covers 1990-03-26 to 2018-03-27.
# NWL Stocker Initialized. Data covers 1984-07-19 to 2018-03-27.
# GD Stocker Initialized. Data covers 1977-01-03 to 2018-03-27.
# AMGN Stocker Initialized. Data covers 1984-09-07 to 2018-03-27.

# %%
# originalDict = tickerobjs
# tickerobjs = tickerobjs[:50]

for i, (k, v) in enumerate(tickerobjs.items()): 
    print(i, k, v)
# Out:
# 0 wfc <stocker.Stocker object at 0x7fcfb8145c50>
# 1 flir <stocker.Stocker object at 0x7fcfb8148208>
# 2 sbac <stocker.Stocker object at 0x7fd06fda3710>
# 3 vno <stocker.Stocker object at 0x7fd06fd8f588>
# 4 mat <stocker.Stocker object at 0x7fd04565f128>
# 5 zion <stocker.Stocker object at 0x7fd06fd84588>
# 6 nwl <stocker.Stocker object at 0x7fcfb8149a90>
# 7 gd <stocker.Stocker object at 0x7fd070a23080>
# 8 amgn <stocker.Stocker object at 0x7fd051570828>

# %% [markdown]
# ### Only keep stocks within the specified date range

# %%
finals = {}
for i, (k, v) in enumerate(tickerobjs.items()):
    try:
        if v.min_date.date() < min_date.date() and v.max_date.date() <= max_date.date():
            finals[k] = v
    except AttributeError:
        pass
print(len(finals))
# print(finals)
tickerobjs = finals
# Out:
# 9

# %% [markdown]
# ### Date features

# %%
stocks_data = {}

for i, (ticker, stocker) in enumerate(tickerobjs.items()):
    df = stocker.make_df(date_range[0], date_range[1])
    # ddd date features
    add_datepart(df, 'Date', drop=False)
    # drop unwanted columns date feature columns
    df = df.drop(['Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start', 'Elapsed'], axis=1)
    df['Is_month_end'] = df['Is_month_end'].astype(int)
    df['Is_month_start'] = df['Is_month_start'].astype(int)
    # setting index as date
    df['Date'] = pd.to_datetime(df.Date,format='%Y-%m-%d')
    df.index = df['Date']
    # sort df by date
    df = df.sort_index(ascending=True, axis=0)
    
    stocks_data[ticker] = df
# Out:
# /home/rafay/portfolio-risk-assessment-using-ml/stocker.py:172: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   trim_df = df[(df['Date'] >= start_date.date()) &
# /home/rafay/portfolio-risk-assessment-using-ml/stocker.py:173: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   (df['Date'] <= end_date.date())]

# %% [markdown]
# ### Fix length issue

# %%
date_list = pd.date_range(start=date_range[0], end=date_range[1], freq='B')
date_df = pd.DataFrame(date_list).rename(columns={0: 'Date'})
date_df.index = date_df['Date']
date_df.rename(columns={'Date': 'Date2'}, inplace=True)

for i, (ticker, df) in enumerate(stocks_data.items()):
    stocks_data[ticker] = pd.concat([df, date_df], ignore_index=False, axis=1)

# %%
TRAIN_SPLIT = 0.8  # 80% of total dataset
VAL_TEST_SPLIT = 0.5  # 50% of the remaining dataset


total_count = len(stocks_data[list(stocks_data.keys())[0]])
train_count = int(total_count * TRAIN_SPLIT)
left = total_count - train_count
valid_count = int(left * VAL_TEST_SPLIT)
test_count = int(left - valid_count)

print(sum([train_count, valid_count, test_count]))
total_count, train_count, valid_count, test_count
# Out:
# 2609
# (2609, 2087, 261, 261)

# %% [markdown]
# ### Create new dataset with required columns

# %%
pick_columns = {
    'Adj. Open', 'Adj. High', 'Adj. Low', 'Adj. Close', 'Adj. Volume', 'Month', 'Week', 'Day', 'Dayofweek', 
    'Dayofyear', 'Is_month_end', 'Is_month_start'
}
y_column = {'Adj. Close'}
x_columns = pick_columns - y_column

for i, (ticker, df) in enumerate(stocks_data.items()):
    # creating new dataframe

    new_data = pd.DataFrame(df, columns=pick_columns).interpolate(limit_direction='both')
        
    x_df = pd.DataFrame(new_data, columns=x_columns)
    y_df = pd.DataFrame(new_data, columns=y_column)
    stocks_data[ticker] = {
        'x': x_df, 'y': y_df,
        'x_train': x_df[0:train_count], 'y_train': y_df[0:train_count],
        'x_valid': x_df[train_count:train_count+valid_count], 'y_valid': y_df[train_count:train_count+valid_count],
        'x_test': x_df[train_count+valid_count:], 'y_test': y_df[train_count+valid_count:],
        'new_data': new_data
    }

# %%
from numpy import hstack
from keras.preprocessing.sequence import TimeseriesGenerator

for i, (ticker, ds) in enumerate(stocks_data.items()):
    x_series = []
    y_series = []
    x_train_series = []
    y_train_series = []
    x_valid_series = []
    y_valid_series = []
    x_test_series = []
    y_test_series = []
    
    ds['x_values'] = ds['x'].values
    ds['y_values'] = ds['y'].values
    
    ds['x_train_values'] = ds['x_train'].values
    ds['y_train_values'] = ds['y_train'].values
    
    ds['x_valid_values'] = ds['x_valid'].values
    ds['y_valid_values'] = ds['y_valid'].values
    
    ds['x_test_values'] = ds['x_test'].values
    ds['y_test_values'] = ds['y_test'].values
    
    # Append values
    x_series.append(ds['x_values'])
    y_series.append(ds['y_values'])
    
    x_train_series.append(ds['x_train_values'])
    y_train_series.append(ds['y_train_values'])
    
    x_valid_series.append(ds['x_valid_values'])
    y_valid_series.append(ds['y_valid_values'])
    
    x_test_series.append(ds['x_test_values'])
    y_test_series.append(ds['y_test_values'])
    

    x_dataset = hstack(tuple(x_series))
    y_dataset = hstack(tuple(y_series))

    x_train_dataset = hstack(tuple(x_train_series))
    y_train_dataset = hstack(tuple(y_train_series))

    x_valid_dataset = hstack(tuple(x_valid_series))
    y_valid_dataset = hstack(tuple(y_valid_series))

    x_test_dataset = hstack(tuple(x_test_series))
    y_test_dataset = hstack(tuple(y_test_series))

    # fit scalers on full series
    x_scaler = MinMaxScaler(feature_range=(0, 1))
    y_scaler = MinMaxScaler(feature_range=(0, 1))

    x_dataset = x_scaler.fit_transform(x_dataset)
    y_dataset = y_scaler.fit_transform(y_dataset)
    
    # Scale train and validation datasets
    x_train_dataset = x_scaler.transform(x_train_dataset)
    y_train_dataset = y_scaler.transform(y_train_dataset)

    x_valid_dataset = x_scaler.transform(x_valid_dataset)
    y_valid_dataset = y_scaler.transform(y_valid_dataset)

    x_test_dataset = x_scaler.transform(x_test_dataset)
    y_test_dataset = y_scaler.transform(y_test_dataset)
    
    ds['x_train_dataset'] = x_train_dataset
    ds['y_train_dataset'] = y_train_dataset
    
    ds['x_valid_dataset'] = x_valid_dataset
    ds['y_valid_dataset'] = y_valid_dataset
    
    ds['x_test_dataset'] = x_test_dataset
    ds['y_test_dataset'] = y_test_dataset
    
    # Store feature scalers
    ds['x_scaler'] = x_scaler
    ds['y_scaler'] = y_scaler
    
    print('*' * 5 + 'Train shapes for ' + ticker)
    print(x_train_dataset.shape, y_train_dataset.shape) 
    
    print('*' * 5 + 'Validation shapes for ' + ticker)
    print(x_valid_dataset.shape, y_valid_dataset.shape) 
    
    print('*' * 5 + 'Test shapes for ' + ticker)
    print(x_test_dataset.shape, y_test_dataset.shape)
# Out:
# *****Train shapes for wfc
# (2087, 11) (2087, 1)
# *****Validation shapes for wfc
# (261, 11) (261, 1)
# *****Test shapes for wfc
# (261, 11) (261, 1)
# *****Train shapes for flir
# (2087, 11) (2087, 1)
# *****Validation shapes for flir
# (261, 11) (261, 1)
# *****Test shapes for flir
# (261, 11) (261, 1)
# *****Train shapes for sbac
# (2087, 11) (2087, 1)
# *****Validation shapes for sbac
# (261, 11) (261, 1)
# *****Test shapes for sbac
# (261, 11) (261, 1)
# *****Train shapes for vno
# (2087, 11) (2087, 1)
# *****Validation shapes for vno
# (261, 11) (261, 1)
# *****Test shapes for vno
# (261, 11) (261, 1)
# *****Train shapes for mat
# (2087, 11) (2087, 1)
# *****Validation shapes for mat
# (261, 11) (261, 1)
# *****Test shapes for mat
# (261, 11) (261, 1)
# *****Train shapes for zion
# (2087, 11) (2087, 1)
# *****Validation shapes for zion
# (261, 11) (261, 1)
# *****Test shapes for zion
# (261, 11) (261, 1)
# *****Train shapes for nwl
# (2087, 11) (2087, 1)
# *****Validation shapes for nwl
# (261, 11) (261, 1)
# *****Test shapes for nwl
# (261, 11) (261, 1)
# *****Train shapes for gd
# (2087, 11) (2087, 1)
# *****Validation shapes for gd
# (261, 11) (261, 1)
# *****Test shapes for gd
# (261, 11) (261, 1)
# *****Train shapes for amgn
# (2087, 11) (2087, 1)
# *****Validation shapes for amgn
# (261, 11) (261, 1)
# *****Test shapes for amgn
# (261, 11) (261, 1)

# %% [markdown]
# ### Create TimeseriesGenerators

# %%
window_length = 90
BATCH_SIZE = int(window_length / 5)

for i, (ticker, ds) in enumerate(stocks_data.items()):
    x_train_dataset = ds['x_train_dataset']
    y_train_dataset = ds['y_train_dataset']
    
    x_valid_dataset = ds['x_valid_dataset']
    y_valid_dataset = ds['y_valid_dataset']
    
    x_test_dataset = ds['x_test_dataset']
    y_test_dataset = ds['y_test_dataset']
    
    train_generator = TimeseriesGenerator(x_train_dataset, y_train_dataset, length=window_length, batch_size=BATCH_SIZE)
    print('Train samples for {}: {}'.format(ticker, len(train_generator)))

    valid_generator = TimeseriesGenerator(x_valid_dataset, y_valid_dataset, length=window_length, batch_size=BATCH_SIZE)
    print('Validation samples for {}: {}'.format(ticker, len(valid_generator)))

    test_generator = TimeseriesGenerator(x_test_dataset, y_test_dataset, length=window_length, batch_size=BATCH_SIZE)
    print('Test samples for {}: {}'.format(ticker, len(test_generator)))
    
    ds['train_generator'] = train_generator
    ds['valid_generator'] = valid_generator
    ds['test_generator'] = test_generator
# Out:
# Train samples for wfc: 111
# Validation samples for wfc: 10
# Test samples for wfc: 10
# Train samples for flir: 111
# Validation samples for flir: 10
# Test samples for flir: 10
# Train samples for sbac: 111
# Validation samples for sbac: 10
# Test samples for sbac: 10
# Train samples for vno: 111
# Validation samples for vno: 10
# Test samples for vno: 10
# Train samples for mat: 111
# Validation samples for mat: 10
# Test samples for mat: 10
# Train samples for zion: 111
# Validation samples for zion: 10
# Test samples for zion: 10
# Train samples for nwl: 111
# Validation samples for nwl: 10
# Test samples for nwl: 10
# Train samples for gd: 111
# Validation samples for gd: 10
# Test samples for gd: 10
# Train samples for amgn: 111
# Validation samples for amgn: 10
# Test samples for amgn: 10

# %% [markdown]
# ### Fit LSTM Model

# %%
EPOCHS = 20

for i, (ticker, ds) in enumerate(stocks_data.items()):
    train_generator = ds['train_generator']
    valid_generator = ds['valid_generator']
    test_generator = ds['test_generator']
    
    OUTPUT_SIZE = 1
    
    model = Sequential()
    model.add(LSTM(units=50, return_sequences=True, input_shape=(window_length, OUTPUT_SIZE * len(x_columns))))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50))
    model.add(Dropout(0.2))
    model.add(Dense(OUTPUT_SIZE))

    model.compile(loss='mean_squared_error', optimizer='adam')

    # Tensorboard
    tensorboard = TensorBoard(log_dir='logs/{}-{}'.format(ticker, time()))
    
    # Checkpoint
    filepath='models/{}.weights.best.hdf5'.format(ticker)
#     checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
    callbacks_list = [tensorboard]
    
    print('*' * 5 + 'Training for {}'.format(ticker))
    model.fit_generator(
        train_generator, 
        validation_data=valid_generator, 
        shuffle=False,
        epochs=EPOCHS, 
        verbose=1, 
        callbacks=callbacks_list
    )
    model.save(filepath)
    
    
    
    # --Plots while training
    val_loss = model.evaluate_generator(valid_generator)
    print('Val loss for {}: {}'.format(ticker, val_loss))
    
    # Make test predictions
    test_predict = model.predict_generator(test_generator)
    predicted_df = pd.DataFrame(y_scaler.inverse_transform(test_predict))
    predicted_df = predicted_df.rename(columns={0: ticker})
    
    original_test = stocks_data[ticker]['y_test'].iloc[window_length:]
    predicted_df.index = original_test.index
    
    predicted_ticker = pd.concat([predicted_df[ticker], original_test], axis=1)
    
    # %matplotlib inline
    plt.figure(figsize=(32, 20))

    plt.plot(predicted_ticker[ticker], linewidth=1, alpha=0.8)
    plt.plot(stocks_data[ticker]['y'], linewidth=1, alpha=0.8)
    plt.title('Plot for {}, val loss: {}'.format(ticker.upper(), val_loss))
    plt.savefig('plots/{}'.format(ticker))
#     plt.show()
# Out:
# *****Training for wfc
# Epoch 1/20
# 111/111 [==============================] - 32s 284ms/step - loss: 0.0089 - val_loss: 0.0218
# Epoch 2/20
# 111/111 [==============================] - 26s 237ms/step - loss: 0.0060 - val_loss: 0.0029
# Epoch 3/20
# 111/111 [==============================] - 27s 243ms/step - loss: 0.0053 - val_loss: 0.0023
# Epoch 4/20
# 111/111 [==============================] - 26s 237ms/step - loss: 0.0052 - val_loss: 0.0021
# Epoch 5/20
# 111/111 [==============================] - 26s 235ms/step - loss: 0.0057 - val_loss: 0.0029
# Epoch 6/20
# 111/111 [==============================] - 28s 249ms/step - loss: 0.0058 - val_loss: 0.0025
# Epoch 7/20
# 111/111 [==============================] - 26s 234ms/step - loss: 0.0062 - val_loss: 0.0040
# Epoch 8/20
# 111/111 [==============================] - 26s 235ms/step - loss: 0.0062 - val_loss: 0.0037
# Epoch 9/20
# 111/111 [==============================] - 28s 250ms/step - loss: 0.0061 - val_loss: 0.0036
# Epoch 10/20
# 111/111 [==============================] - 26s 235ms/step - loss: 0.0058 - val_loss: 0.0045
# Epoch 11/20
# 111/111 [==============================] - 26s 236ms/step - loss: 0.0061 - val_loss: 0.0027
# Epoch 12/20
# 111/111 [==============================] - 27s 246ms/step - loss: 0.0050 - val_loss: 0.0043
# Epoch 13/20
# 111/111 [==============================] - 26s 234ms/step - loss: 0.0057 - val_loss: 0.0021
# Epoch 14/20
# 111/111 [==============================] - 26s 235ms/step - loss: 0.0045 - val_loss: 0.0031
# Epoch 15/20
# 111/111 [==============================] - 27s 243ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 16/20
# 111/111 [==============================] - 26s 235ms/step - loss: 0.0047 - val_loss: 0.0032
# Epoch 17/20
# 111/111 [==============================] - 27s 240ms/step - loss: 0.0042 - val_loss: 0.0034
# Epoch 18/20
# 111/111 [==============================] - 27s 244ms/step - loss: 0.0034 - val_loss: 0.0042
# Epoch 19/20
# 111/111 [==============================] - 26s 233ms/step - loss: 0.0034 - val_loss: 0.0023
# Epoch 20/20
# 111/111 [==============================] - 26s 233ms/step - loss: 0.0028 - val_loss: 0.0026
# Val loss for wfc: 0.0026260688962218793
# /home/rafay/miniconda3/envs/lstmstocks/lib/python3.6/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# *****Training for flir
# Epoch 1/20
# 111/111 [==============================] - 29s 265ms/step - loss: 0.0193 - val_loss: 0.0069
# Epoch 2/20
# 111/111 [==============================] - 26s 236ms/step - loss: 0.0082 - val_loss: 0.0064
# Epoch 3/20
# 111/111 [==============================] - 26s 235ms/step - loss: 0.0067 - val_loss: 0.0055
# Epoch 4/20
# 111/111 [==============================] - 27s 244ms/step - loss: 0.0054 - val_loss: 0.0039
# Epoch 5/20
# 111/111 [==============================] - 26s 233ms/step - loss: 0.0037 - val_loss: 0.0035
# Epoch 6/20
# 111/111 [==============================] - 26s 232ms/step - loss: 0.0032 - val_loss: 0.0027
# Epoch 7/20
# 111/111 [==============================] - 27s 244ms/step - loss: 0.0029 - val_loss: 0.0036
# Epoch 8/20
# 111/111 [==============================] - 27s 241ms/step - loss: 0.0026 - val_loss: 0.0029
# Epoch 9/20
# 111/111 [==============================] - 26s 236ms/step - loss: 0.0026 - val_loss: 0.0033
# Epoch 10/20
# 111/111 [==============================] - 27s 244ms/step - loss: 0.0025 - val_loss: 0.0030
# Epoch 11/20
# 111/111 [==============================] - 26s 235ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 12/20
# 111/111 [==============================] - 27s 247ms/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 13/20
# 111/111 [==============================] - 27s 246ms/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 14/20
# 111/111 [==============================] - 26s 234ms/step - loss: 0.0020 - val_loss: 0.0025
# Epoch 15/20
# 111/111 [==============================] - 26s 237ms/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 16/20
# 111/111 [==============================] - 27s 245ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 17/20
# 111/111 [==============================] - 26s 237ms/step - loss: 0.0020 - val_loss: 0.0025
# Epoch 18/20
# 111/111 [==============================] - 26s 236ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 19/20
# 111/111 [==============================] - 27s 244ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 20/20
# 111/111 [==============================] - 27s 241ms/step - loss: 0.0017 - val_loss: 0.0023
# Val loss for flir: 0.0023115763661304585
# *****Training for sbac
# Epoch 1/20
# 111/111 [==============================] - 27s 246ms/step - loss: 0.0059 - val_loss: 0.0013
# Epoch 2/20
# 111/111 [==============================] - 27s 244ms/step - loss: 0.0073 - val_loss: 0.0030
# Epoch 3/20
# 111/111 [==============================] - 26s 237ms/step - loss: 0.0076 - val_loss: 0.0015
# Epoch 4/20
# 111/111 [==============================] - 27s 246ms/step - loss: 0.0081 - val_loss: 0.0025
# Epoch 5/20
# 111/111 [==============================] - 27s 246ms/step - loss: 0.0085 - val_loss: 0.0015
# Epoch 6/20
# 111/111 [==============================] - 26s 237ms/step - loss: 0.0091 - val_loss: 0.0013
# Epoch 7/20
# 111/111 [==============================] - 26s 235ms/step - loss: 0.0107 - val_loss: 0.0014
# Epoch 8/20
# 111/111 [==============================] - 27s 245ms/step - loss: 0.0116 - val_loss: 0.0019
# Epoch 9/20
# 111/111 [==============================] - 26s 237ms/step - loss: 0.0105 - val_loss: 8.4772e-04
# Epoch 10/20
# 111/111 [==============================] - 26s 234ms/step - loss: 0.0075 - val_loss: 7.5057e-04
# Epoch 11/20
# 111/111 [==============================] - 27s 246ms/step - loss: 0.0045 - val_loss: 7.5589e-04
# Epoch 12/20
# 111/111 [==============================] - 26s 234ms/step - loss: 0.0024 - val_loss: 7.9422e-04
# Epoch 13/20
# 111/111 [==============================] - 26s 235ms/step - loss: 0.0015 - val_loss: 6.5708e-04
# Epoch 14/20
# 111/111 [==============================] - 27s 243ms/step - loss: 0.0012 - val_loss: 6.2675e-04
# Epoch 15/20
# 111/111 [==============================] - 27s 247ms/step - loss: 0.0011 - val_loss: 6.5193e-04
# Epoch 16/20
# 111/111 [==============================] - 26s 235ms/step - loss: 0.0010 - val_loss: 7.4065e-04
# Epoch 17/20
# 111/111 [==============================] - 27s 245ms/step - loss: 0.0011 - val_loss: 9.3222e-04
# Epoch 18/20
# 111/111 [==============================] - 26s 235ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 19/20
# 111/111 [==============================] - 26s 236ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 20/20
# 111/111 [==============================] - 27s 245ms/step - loss: 0.0014 - val_loss: 0.0014
# Val loss for sbac: 0.0013760431657398218
# *****Training for vno
# Epoch 1/20
# 111/111 [==============================] - 28s 248ms/step - loss: 0.0180 - val_loss: 0.0105
# Epoch 2/20
# 111/111 [==============================] - 27s 241ms/step - loss: 0.0109 - val_loss: 0.0067
# Epoch 3/20
# 111/111 [==============================] - 27s 245ms/step - loss: 0.0121 - val_loss: 0.0097
# Epoch 4/20
# 111/111 [==============================] - 26s 235ms/step - loss: 0.0105 - val_loss: 0.0135
# Epoch 5/20
# 111/111 [==============================] - 26s 236ms/step - loss: 0.0090 - val_loss: 0.0100
# Epoch 6/20
# 111/111 [==============================] - 28s 248ms/step - loss: 0.0082 - val_loss: 0.0126
# Epoch 7/20
# 111/111 [==============================] - 27s 247ms/step - loss: 0.0072 - val_loss: 0.0121
# Epoch 8/20
# 111/111 [==============================] - 26s 238ms/step - loss: 0.0067 - val_loss: 0.0105
# Epoch 9/20
# 111/111 [==============================] - 27s 245ms/step - loss: 0.0065 - val_loss: 0.0100
# Epoch 10/20
# 111/111 [==============================] - 26s 236ms/step - loss: 0.0071 - val_loss: 0.0104
# Epoch 11/20
# 111/111 [==============================] - 26s 236ms/step - loss: 0.0078 - val_loss: 0.0089
# Epoch 12/20
# 111/111 [==============================] - 27s 245ms/step - loss: 0.0085 - val_loss: 0.0049
# Epoch 13/20
# 111/111 [==============================] - 26s 235ms/step - loss: 0.0093 - val_loss: 0.0024
# Epoch 14/20
# 111/111 [==============================] - 27s 241ms/step - loss: 0.0103 - val_loss: 0.0024
# Epoch 15/20
# 111/111 [==============================] - 27s 244ms/step - loss: 0.0102 - val_loss: 0.0020
# Epoch 16/20
# 111/111 [==============================] - 26s 237ms/step - loss: 0.0101 - val_loss: 0.0021
# Epoch 17/20
# 111/111 [==============================] - 26s 236ms/step - loss: 0.0100 - val_loss: 0.0033
# Epoch 18/20
# 111/111 [==============================] - 29s 258ms/step - loss: 0.0099 - val_loss: 0.0021
# Epoch 19/20
# 111/111 [==============================] - 26s 236ms/step - loss: 0.0089 - val_loss: 0.0019
# Epoch 20/20
# 111/111 [==============================] - 26s 235ms/step - loss: 0.0079 - val_loss: 0.0026
# Val loss for vno: 0.0025515902732302876
# *****Training for mat
# Epoch 1/20
# 111/111 [==============================] - 28s 254ms/step - loss: 0.0111 - val_loss: 0.0427
# Epoch 2/20
# 111/111 [==============================] - 26s 238ms/step - loss: 0.0079 - val_loss: 0.0506
# Epoch 3/20
# 111/111 [==============================] - 27s 242ms/step - loss: 0.0089 - val_loss: 0.0402
# Epoch 4/20
# 111/111 [==============================] - 27s 241ms/step - loss: 0.0088 - val_loss: 0.0510
# Epoch 5/20
# 111/111 [==============================] - 27s 243ms/step - loss: 0.0083 - val_loss: 0.0517
# Epoch 6/20
# 111/111 [==============================] - 27s 243ms/step - loss: 0.0084 - val_loss: 0.0486
# Epoch 7/20
# 111/111 [==============================] - 27s 241ms/step - loss: 0.0074 - val_loss: 0.0495
# Epoch 8/20
# 111/111 [==============================] - 26s 236ms/step - loss: 0.0084 - val_loss: 0.0546
# Epoch 9/20
# 111/111 [==============================] - 27s 244ms/step - loss: 0.0082 - val_loss: 0.0510
# Epoch 10/20
# 111/111 [==============================] - 27s 242ms/step - loss: 0.0091 - val_loss: 0.0517
# Epoch 11/20
# 111/111 [==============================] - 26s 236ms/step - loss: 0.0101 - val_loss: 0.0547
# Epoch 12/20
# 111/111 [==============================] - 27s 240ms/step - loss: 0.0113 - val_loss: 0.0559
# Epoch 13/20
# 111/111 [==============================] - 27s 241ms/step - loss: 0.0149 - val_loss: 0.0528
# Epoch 14/20
# 111/111 [==============================] - 26s 236ms/step - loss: 0.0179 - val_loss: 0.0447
# Epoch 15/20
# 111/111 [==============================] - 26s 238ms/step - loss: 0.0202 - val_loss: 0.0295
# Epoch 16/20
# 111/111 [==============================] - 27s 246ms/step - loss: 0.0209 - val_loss: 0.0225
# Epoch 17/20
# 111/111 [==============================] - 26s 237ms/step - loss: 0.0203 - val_loss: 0.0154
# Epoch 18/20
# 111/111 [==============================] - 26s 239ms/step - loss: 0.0189 - val_loss: 0.0125
# Epoch 19/20
# 111/111 [==============================] - 27s 242ms/step - loss: 0.0168 - val_loss: 0.0117
# Epoch 20/20
# 111/111 [==============================] - 26s 237ms/step - loss: 0.0148 - val_loss: 0.0093
# Val loss for mat: 0.009258985274324292
# *****Training for zion
# Epoch 1/20
# 111/111 [==============================] - 30s 273ms/step - loss: 0.0277 - val_loss: 0.0065
# Epoch 2/20
# 111/111 [==============================] - 26s 236ms/step - loss: 0.0090 - val_loss: 0.0062
# Epoch 3/20
# 111/111 [==============================] - 26s 237ms/step - loss: 0.0078 - val_loss: 0.0057
# Epoch 4/20
# 111/111 [==============================] - 27s 246ms/step - loss: 0.0064 - val_loss: 0.0049
# Epoch 5/20
# 111/111 [==============================] - 26s 237ms/step - loss: 0.0052 - val_loss: 0.0040
# Epoch 6/20
# 111/111 [==============================] - 26s 238ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 7/20
# 111/111 [==============================] - 28s 248ms/step - loss: 0.0038 - val_loss: 0.0042
# Epoch 8/20
# 111/111 [==============================] - 26s 236ms/step - loss: 0.0034 - val_loss: 0.0029
# Epoch 9/20
# 111/111 [==============================] - 26s 239ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 10/20
# 111/111 [==============================] - 27s 247ms/step - loss: 0.0027 - val_loss: 0.0034
# Epoch 11/20
# 111/111 [==============================] - 26s 237ms/step - loss: 0.0025 - val_loss: 0.0031
# Epoch 12/20
# 111/111 [==============================] - 27s 248ms/step - loss: 0.0024 - val_loss: 0.0026
# Epoch 13/20
# 111/111 [==============================] - 27s 246ms/step - loss: 0.0025 - val_loss: 0.0028
# Epoch 14/20
# 111/111 [==============================] - 26s 237ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 15/20
# 111/111 [==============================] - 26s 237ms/step - loss: 0.0024 - val_loss: 0.0032
# Epoch 16/20
# 111/111 [==============================] - 27s 245ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 17/20
# 111/111 [==============================] - 26s 237ms/step - loss: 0.0024 - val_loss: 0.0033
# Epoch 18/20
# 111/111 [==============================] - 26s 234ms/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 19/20
# 111/111 [==============================] - 28s 250ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 20/20
# 111/111 [==============================] - 26s 236ms/step - loss: 0.0019 - val_loss: 0.0021
# Val loss for zion: 0.002100300909277346
# *****Training for nwl
# Epoch 1/20
# 111/111 [==============================] - 28s 248ms/step - loss: 0.0085 - val_loss: 0.0122
# Epoch 2/20
# 111/111 [==============================] - 27s 247ms/step - loss: 0.0055 - val_loss: 0.0086
# Epoch 3/20
# 111/111 [==============================] - 27s 241ms/step - loss: 0.0084 - val_loss: 0.0146
# Epoch 4/20
# 111/111 [==============================] - 27s 244ms/step - loss: 0.0092 - val_loss: 0.0258
# Epoch 5/20
# 111/111 [==============================] - 27s 247ms/step - loss: 0.0087 - val_loss: 0.0239
# Epoch 6/20
# 111/111 [==============================] - 26s 237ms/step - loss: 0.0079 - val_loss: 0.0128
# Epoch 7/20
# 111/111 [==============================] - 26s 237ms/step - loss: 0.0082 - val_loss: 0.0150
# Epoch 8/20
# 111/111 [==============================] - 27s 245ms/step - loss: 0.0076 - val_loss: 0.0104
# Epoch 9/20
# 111/111 [==============================] - 26s 237ms/step - loss: 0.0073 - val_loss: 0.0039
# Epoch 10/20
# 111/111 [==============================] - 27s 242ms/step - loss: 0.0075 - val_loss: 0.0048
# Epoch 11/20
# 111/111 [==============================] - 27s 244ms/step - loss: 0.0069 - val_loss: 0.0040
# Epoch 12/20
# 111/111 [==============================] - 26s 236ms/step - loss: 0.0046 - val_loss: 0.0022
# Epoch 13/20
# 111/111 [==============================] - 26s 236ms/step - loss: 0.0027 - val_loss: 0.0014
# Epoch 14/20
# 111/111 [==============================] - 27s 245ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 15/20
# 111/111 [==============================] - 27s 247ms/step - loss: 0.0012 - val_loss: 0.0025
# Epoch 16/20
# 111/111 [==============================] - 26s 236ms/step - loss: 0.0011 - val_loss: 0.0039
# Epoch 17/20
# 111/111 [==============================] - 27s 244ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 18/20
# 111/111 [==============================] - 26s 234ms/step - loss: 0.0010 - val_loss: 9.1350e-04
# Epoch 19/20
# 111/111 [==============================] - 26s 235ms/step - loss: 0.0010 - val_loss: 9.1627e-04
# Epoch 20/20
# 111/111 [==============================] - 27s 245ms/step - loss: 9.2541e-04 - val_loss: 0.0011
# Val loss for nwl: 0.0011463202283362318
# *****Training for gd
# Epoch 1/20
# 111/111 [==============================] - 28s 254ms/step - loss: 0.0060 - val_loss: 0.0046
# Epoch 2/20
# 111/111 [==============================] - 26s 238ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 3/20
# 111/111 [==============================] - 27s 241ms/step - loss: 0.0044 - val_loss: 0.0054
# Epoch 4/20
# 111/111 [==============================] - 26s 234ms/step - loss: 0.0051 - val_loss: 0.0026
# Epoch 5/20
# 111/111 [==============================] - 26s 237ms/step - loss: 0.0062 - val_loss: 0.0037
# Epoch 6/20
# 111/111 [==============================] - 28s 248ms/step - loss: 0.0074 - val_loss: 0.0062
# Epoch 7/20
# 111/111 [==============================] - 26s 236ms/step - loss: 0.0089 - val_loss: 0.0116
# Epoch 8/20
# 111/111 [==============================] - 26s 238ms/step - loss: 0.0090 - val_loss: 0.0118
# Epoch 9/20
# 111/111 [==============================] - 27s 241ms/step - loss: 0.0093 - val_loss: 0.0025
# Epoch 10/20
# 111/111 [==============================] - 26s 235ms/step - loss: 0.0090 - val_loss: 0.0033
# Epoch 11/20
# 111/111 [==============================] - 26s 237ms/step - loss: 0.0079 - val_loss: 0.0028
# Epoch 12/20
# 111/111 [==============================] - 27s 246ms/step - loss: 0.0062 - val_loss: 0.0028
# Epoch 13/20
# 111/111 [==============================] - 26s 232ms/step - loss: 0.0040 - val_loss: 0.0028
# Epoch 14/20
# 111/111 [==============================] - 26s 234ms/step - loss: 0.0024 - val_loss: 0.0035
# Epoch 15/20
# 111/111 [==============================] - 27s 240ms/step - loss: 0.0016 - val_loss: 0.0044
# Epoch 16/20
# 111/111 [==============================] - 26s 233ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 17/20
# 111/111 [==============================] - 28s 249ms/step - loss: 0.0057 - val_loss: 0.0097
# Epoch 2/20
# 111/111 [==============================] - 26s 235ms/step - loss: 0.0085 - val_loss: 0.0027
# Epoch 3/20
# 111/111 [==============================] - 26s 235ms/step - loss: 0.0112 - val_loss: 0.0141
# Epoch 6/20
# 111/111 [==============================] - 27s 243ms/step - loss: 0.0105 - val_loss: 0.0109
# Epoch 7/20
# 111/111 [==============================] - 26s 235ms/step - loss: 0.0082 - val_loss: 0.0076
# Epoch 8/20
# 111/111 [==============================] - 26s 233ms/step - loss: 0.0064 - val_loss: 0.0056
# Epoch 9/20
# 111/111 [==============================] - 27s 243ms/step - loss: 0.0045 - val_loss: 0.0061
# Epoch 10/20
# 111/111 [==============================] - 27s 240ms/step - loss: 0.0029 - val_loss: 0.0041
# Epoch 11/20
# 111/111 [==============================] - 26s 239ms/step - loss: 0.0019 - val_loss: 0.0045
# Epoch 14/20
# 111/111 [==============================] - 26s 238ms/step - loss: 0.0023 - val_loss: 0.0036
# Epoch 17/20
# 111/111 [==============================] - 26s 238ms/step - loss: 0.0027 - val_loss: 0.0038
# Epoch 19/20
# 111/111 [==============================] - 26s 234ms/step - loss: 0.0024 - val_loss: 0.0039
# Val loss for amgn: 0.0039042493904401596

# %% [markdown]
# ### Final analysis

# %%
for i, (ticker, ds) in enumerate(stocks_data.items()):
    train_generator = ds['train_generator']
    valid_generator = ds['valid_generator']
    test_generator = ds['test_generator']
    
    x_scaler = ds['x_scaler']
    y_scaler = ds['y_scaler']
    
    filepath='models/{}.weights.best.hdf5'.format(ticker)
    OUTPUT_SIZE = 1
    
    model = Sequential()
    model.add(LSTM(units=50, return_sequences=True, input_shape=(window_length, OUTPUT_SIZE * len(x_columns))))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50))
    model.add(Dropout(0.2))
    model.add(Dense(OUTPUT_SIZE))
    
    model.load_weights(filepath)

    model.compile(loss='mean_squared_error', optimizer='adam')
    
    val_loss = model.evaluate_generator(valid_generator)
    print('Val loss for {}: {}'.format(ticker, val_loss))
    
    # Make test predictions
    test_predict = model.predict_generator(test_generator)
    predicted_df = pd.DataFrame(y_scaler.inverse_transform(test_predict))
    predicted_df = predicted_df.rename(columns={0: ticker})
    
    original_test = stocks_data[ticker]['y_test'].iloc[window_length:]
    predicted_df.index = original_test.index
    
    predicted_ticker = pd.concat([predicted_df[ticker], original_test], axis=1)
    
    # %matplotlib inline
    plt.figure(figsize=(32, 20))

    plt.plot(predicted_ticker[ticker], linewidth=1, alpha=0.8)
    plt.plot(stocks_data[ticker]['y'], linewidth=1, alpha=0.8)
    plt.title('Plot for {}, val loss: {}'.format(ticker.upper(), val_loss))
    plt.savefig('plots/{}'.format(ticker))
    plt.show()
# Out:
# Val loss for msci: 0.0045862981534906125

# %% [markdown]
# ### Calculate on validation dataset

# %%
model.evaluate_generator(valid_generator)
# Out:
# 0.0006561233963829613

# %% [markdown]
# ### Make peridiction

# %%
test_predict = model.predict_generator(test_generator)

# %%
first = list(stocks_data.keys())[0]

predicted_df = pd.DataFrame(y_scaler.inverse_transform(test_predict))
predicted_df = predicted_df.rename(columns={0: first})
original_amzn = stocks_data[first]['y_test'].iloc[window_length:]
predicted_df.index = original_amzn.index

# %%
predicted_amzn = pd.concat([predicted_df[first], original_amzn], axis=1)

# %%
# %matplotlib inline
plt.figure(figsize=(32, 20))

plt.plot(predicted_amzn[first], linewidth=1, alpha=0.8)
plt.plot(stocks_data[first]['y'], linewidth=1, alpha=0.8)
